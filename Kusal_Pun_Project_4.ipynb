# %% [markdown]
# # ChatData
#
# ## Sqlite
# We are using a file system called **sqlite**. It looks and acts like a real single user relational database (RDB). sqlite3 comes packaged with python. You do not need to install the library. You simply import it (as below).
#
# - We are using Pandas to write and read to sqlite. Pandas will manage a lot of the complexity of dealing with a RDB. There are other ways of reading and writing to a RDB that are VERY common and often used in production systems.
#
# - The most common other way is to read or write to the RDB row by row. As you can see Pandas puts the entire dataframe into the RDB or extracts a new dataframe from the RDB. These are not row by row operations. These are set operations. Set operations ARE more efficient. However, it is common to use row by row operations to avoid needing large memory computers to hold the dataframes. One row only takes a few bytes. An entire dataframe could be many gigabytes and even petabytes of data. Obviously you will end up with problems with your compute resource if your files are this big. This will not happen to you in this activity and may never happen to you while you are a data analyst. Please just be aware of this.
#
# - This activity is primarily about querying a RDB, so, we are using a simple way that Pandas provides. If you want to learn the more complex way, just google 'reading and wrting to a relational database using python'. There are many resources to learn from.
#
# - The data types that sqlite supports are quite limited. for example, it does not have a DATE type.  This is not a challenge for this project. However, more sophisticated database systems,such as Postgresql, have a large array of data types, such as "DATE", etc. that give those systems additional capability.
#
# - All of the SQL queries could also be performed on the Pandas DataFrames directly.  You may want to try this yourself for comparison (but make sure you do the SQL queries first, as this is an exercise in using SQL!).
#
#
# ## SQL Magic
# Within the Jupyter notebook we will be using something called **SQL Magic**.  This provides a convenient way to write SQL queries directly into code cells in the notebook and to read the results back into a Pandas DataFrame.  This makes working with SQL much easier!
#
# Note that you may need to update your sqlite version using `conda update -c anaconda sqlite` in order for the SQL Magic to work correctly.
#
# ## The Data Analysis Lifecycle
# The sections in this notebook follow the stages of the Data Analysis Lifecycle introduced in an earlier activity.  The stages are:
#
# - Acquire
# - Transform
# - Organise
# - Analyse
# - Communicate
# - Maintain

# %% [markdown]
# The requirements document for this project is Template SQL queries.xlsx.

# %% [markdown]
# # Preliminary Steps: Create a Database
# First let's import Sqlite and the other libraries we will need.
#
# db_path = ('C:/Users/kusal/OneDrive - The University of Manchester/Documents/Kusal Pun's Project/chatdata.db')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_path = ("/content/drive/MyDrive/OC/data/")

# %%
db_path = "/content/drive/OC/db/chatdata.db"

# %% [markdown]
# ### Create the Database
# Now we will create the Sqlite database.  Here is some code that does this for you.  We use the `%load_ext` magic command to load the SQL Magic extension and then use `%sql` to connect to the database.

# %%
# Import Libraries
import numpy as np
import pandas as pd
import sqlite3
# !pip install ipython-sql
# %load_ext sql
# Out:
# Requirement already satisfied: ipython-sql in /usr/local/lib/python3.10/dist-packages (0.5.0)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (3.10.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (7.34.0)
# Requirement already satisfied: sqlalchemy>=2.0 in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (2.0.28)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (0.4.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=2.0->ipython-sql) (4.10.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-sql) (4.9.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# If the db does not exist, sqlite will create it.
con = sqlite3.connect('chatdata.db')

# loads sql magic
# %reload_ext sql
# connects sql magic command to the correct db
# %sql sqlite:///chatdata.db

# %% [markdown]
# #### Drop the `queries` table if it already exists
# The queries table will be our record of the queries created to answer the questions from the requirements spreadsheet.  As we will be running this Jupyter notebook a few times, let's drop (i.e. remove) the queries table so that we start fresh each time.  Here is the code to do this.  We use the `%%sql` magic command to tell Jupyter that we are going to write SQL in the cell.

# %%
# %%sql
# DROP TABLE IF EXISTS 'queries'
# Out:
#  * sqlite:///chatdata.db
# Done.
# []

# %% [markdown]
# # Task 1: Load the Data
# Now we can start loading the data.  The tables will be created as we load the data.
#
# Note that some of these files are quite large, so make sure you have plenty of free memory!

# %% [markdown]
# ## Lifecycle Stages: Transform and Organise
# The data has already been processed into 3 clean data files ready for this project:
#
# - queries.csv
# - posts.csv
# - comments.csv
#
# We will load these files into our database.

# %% [markdown]
# ## Lifecycle Stage: Acquire
# The data can be found in the OpenClassrooms instructions for this activity.

# %% [markdown]
# ### Load Comments Data into a `comments` table
# Now we will load the data from the csv files into our sqlite database.
#
# First we load the csv file into a Pandas dataframe:

# %%
comments = pd.read_csv(data_path + "comments.csv")
comments.head()

#Explain what it is telling you
# Out:
#        Id  PostId  Score                                               Text  \
# 0  723182  385124      0  @BenBolker I don't understand. The fit cannot ...
# 1  723183  385124      3  You can't add *less* than (`-min(y)`), but you...
# 2  723186  385137      0  nice. If you felt like doing the work it would...
# 3  723187  385137      0  i.e. `emdbook::curve3d(-sum(dnbinom(y,mu=mu,si...
# 4  723188  385134      0  Don't you mean "so variance should be $\sigma^...
#
#           CreationDate  UserId
# 0  2019-01-01 00:06:39   78575
# 1  2019-01-01 00:09:22    2126
# 2  2019-01-01 00:32:11    2126
# 3  2019-01-01 00:40:36    2126
# 4  2019-01-01 00:41:28  112141

# %% [markdown]
# Now take the comments dataframe and push the data into the Sqlite database table called 'comments':

# %%
# load comments into sqlite
comments.to_sql('comments', con, if_exists='replace', index=False)

#Explain the results what it is telling you

# read back in to prove that it worked
sql = 'SELECT * FROM comments'
comments = pd.read_sql(sql, con)
comments.head()

#Explain the results
# Out:
#        Id  PostId  Score                                               Text  \
# 0  723182  385124      0  @BenBolker I don't understand. The fit cannot ...
# 1  723183  385124      3  You can't add *less* than (`-min(y)`), but you...
# 2  723186  385137      0  nice. If you felt like doing the work it would...
# 3  723187  385137      0  i.e. `emdbook::curve3d(-sum(dnbinom(y,mu=mu,si...
# 4  723188  385134      0  Don't you mean "so variance should be $\sigma^...
#
#           CreationDate  UserId
# 0  2019-01-01 00:06:39   78575
# 1  2019-01-01 00:09:22    2126
# 2  2019-01-01 00:32:11    2126
# 3  2019-01-01 00:40:36    2126
# 4  2019-01-01 00:41:28  112141

# %% [markdown]
# ### Load Other CSVs
# Now that you have seen the code for loading in the comments.csv now do the same to read and write the posts.csv and users.csv to sqlite.
#
# <div style="background-color:lemonchiffon; border:1px solid; padding:5px; margin:5px; font-weight:bold"><font color="crimson">
# TODO: Enter code in the following cells. Insert as many cells as you want to do this.
#     </font></div>

# %%
posts = pd.read_csv(data_path + "posts.csv")
posts.head()
# Out:
#        Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  Score  \
# 0  423497           1            423511         0  2019-08-24 09:39:31      2
# 1  423498           1                 0         0  2019-08-24 09:47:42      1
# 2  423499           1                 0         0  2019-08-24 09:48:26      1
# 3  423500           2                 0    215865  2019-08-24 09:57:01      0
# 4  423502           2                 0    423286  2019-08-24 10:44:52      3
#
#    ViewCount                                               Body  OwnerUserId  \
# 0         68  <p>From wikipedia <a href="https://en.wikipedi...        64552
# 1         24  <p>I am currently doing local sensitivity anal...        87231
# 2         56  <p>I'm an honours student in psychology doing ...       257207
# 3          0  <p>Maybe you can look this <a href="https://me...       106606
# 4          0  <blockquote>\n  <p>Q1) Is my approach valid?</...       220643
#
#   OwnerDisplayName  ...  LastEditorDisplayName         LastEditDate  \
# 0              NaN  ...                    NaN                  NaN
# 1              NaN  ...                    NaN  2019-09-06 12:52:32
# 2              NaN  ...                    NaN                  NaN
# 3              NaN  ...                    NaN                  NaN
# 4              NaN  ...                    NaN  2019-08-24 12:13:46
#
#       LastActivityDate                                              Title  \
# 0  2019-08-24 11:38:54  When are biased estimators with lower MSE pref...
# 1  2019-09-06 12:52:32  How to interpret the result from local sensiti...
# 2  2019-08-25 08:54:17      Power Analysis in G-Power - Mixed Model Anova
# 3  2019-08-24 09:57:01                                                NaN
# 4  2019-08-24 12:13:46                                                NaN
#
#                                  Tags AnswerCount  CommentCount  \
# 0     <bias><unbiased-estimator><mse>           1             0
# 1  <sensitivity-analysis><elasticity>           1             0
# 2                     <anova><gpower>           2             0
# 3                                 NaN           0             0
# 4                                 NaN           0             1
#
#    FavoriteCount           ClosedDate CommunityOwnedDate
# 0              1  2019-08-25 10:25:24                NaN
# 1              0                  NaN                NaN
# 2              0                  NaN                NaN
# 3              0                  NaN                NaN
# 4              0                  NaN                NaN
#
# [5 rows x 21 columns]

# %%
# load comments into sqlite
posts.to_sql('posts', con, if_exists='replace', index=False)

#Explain the results what it is telling you

# read back in to prove that it worked
sql = 'SELECT * FROM posts'
posts = pd.read_sql(sql, con)
posts.head()

#Explain the results
# Out:
#        Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  Score  \
# 0  423497           1            423511         0  2019-08-24 09:39:31      2
# 1  423498           1                 0         0  2019-08-24 09:47:42      1
# 2  423499           1                 0         0  2019-08-24 09:48:26      1
# 3  423500           2                 0    215865  2019-08-24 09:57:01      0
# 4  423502           2                 0    423286  2019-08-24 10:44:52      3
#
#    ViewCount                                               Body  OwnerUserId  \
# 0         68  <p>From wikipedia <a href="https://en.wikipedi...        64552
# 1         24  <p>I am currently doing local sensitivity anal...        87231
# 2         56  <p>I'm an honours student in psychology doing ...       257207
# 3          0  <p>Maybe you can look this <a href="https://me...       106606
# 4          0  <blockquote>\n  <p>Q1) Is my approach valid?</...       220643
#
#   OwnerDisplayName  ...  LastEditorDisplayName         LastEditDate  \
# 0             None  ...                   None                 None
# 1             None  ...                   None  2019-09-06 12:52:32
# 2             None  ...                   None                 None
# 3             None  ...                   None                 None
# 4             None  ...                   None  2019-08-24 12:13:46
#
#       LastActivityDate                                              Title  \
# 0  2019-08-24 11:38:54  When are biased estimators with lower MSE pref...
# 1  2019-09-06 12:52:32  How to interpret the result from local sensiti...
# 2  2019-08-25 08:54:17      Power Analysis in G-Power - Mixed Model Anova
# 3  2019-08-24 09:57:01                                               None
# 4  2019-08-24 12:13:46                                               None
#
#                                  Tags AnswerCount  CommentCount  \
# 0     <bias><unbiased-estimator><mse>           1             0
# 1  <sensitivity-analysis><elasticity>           1             0
# 2                     <anova><gpower>           2             0
# 3                                None           0             0
# 4                                None           0             1
#
#    FavoriteCount           ClosedDate CommunityOwnedDate
# 0              1  2019-08-25 10:25:24               None
# 1              0                 None               None
# 2              0                 None               None
# 3              0                 None               None
# 4              0                 None               None
#
# [5 rows x 21 columns]

# %%
users = pd.read_csv(data_path + "users.csv")
users.head()
# Out:
#        Id  Reputation         CreationDate DisplayName       LastAccessDate  \
# 0  157607          31  2017-04-17 14:50:42  user157607  2019-07-23 16:44:08
# 1  157656         101  2017-04-17 20:08:20  user102859  2019-06-26 13:42:13
# 2  157704         133  2017-04-18 05:10:47      jupiar  2019-11-25 13:32:27
# 3  157709         155  2017-04-18 06:39:18      farmer  2019-02-17 19:44:24
# 4  157755         101  2017-04-18 12:56:17      Miki P  2019-08-12 17:02:21
#
#   WebsiteUrl         Location  \
# 0        NaN              NaN
# 1        NaN              NaN
# 2        NaN  Shanghai, China
# 3        NaN              NaN
# 4        NaN              NaN
#
#                                              AboutMe  Views  UpVotes  \
# 0                                                NaN      0        0
# 1                                                NaN      3        0
# 2  <p>Originally from the U.K, I have an Undergra...      1        1
# 3                                                NaN     16        0
# 4                                                NaN      1        9
#
#    DownVotes                                    ProfileImageUrl  AccountId
# 0          0  https://www.gravatar.com/avatar/2efb161849efa4...   10705183
# 1          0      https://i.stack.imgur.com/eY4ka.jpg?s=128&g=1   10567606
# 2          0  https://www.gravatar.com/avatar/720e20205122c5...    9501631
# 3          0  https://www.gravatar.com/avatar/0f8c4bde3d8f25...   10709837
# 4          0  https://www.gravatar.com/avatar/af088558cd81c5...    7969290

# %%
users.to_sql('users', con, if_exists='replace', index=False)

#Explain the results what it is telling you

# read back in to prove that it worked
sql = 'SELECT * FROM users'
users = pd.read_sql(sql, con)
users.head()
# Out:
#        Id  Reputation         CreationDate DisplayName       LastAccessDate  \
# 0  157607          31  2017-04-17 14:50:42  user157607  2019-07-23 16:44:08
# 1  157656         101  2017-04-17 20:08:20  user102859  2019-06-26 13:42:13
# 2  157704         133  2017-04-18 05:10:47      jupiar  2019-11-25 13:32:27
# 3  157709         155  2017-04-18 06:39:18      farmer  2019-02-17 19:44:24
# 4  157755         101  2017-04-18 12:56:17      Miki P  2019-08-12 17:02:21
#
#   WebsiteUrl         Location  \
# 0       None             None
# 1       None             None
# 2       None  Shanghai, China
# 3       None             None
# 4       None             None
#
#                                              AboutMe  Views  UpVotes  \
# 0                                               None      0        0
# 1                                               None      3        0
# 2  <p>Originally from the U.K, I have an Undergra...      1        1
# 3                                               None     16        0
# 4                                               None      1        9
#
#    DownVotes                                    ProfileImageUrl  AccountId
# 0          0  https://www.gravatar.com/avatar/2efb161849efa4...   10705183
# 1          0      https://i.stack.imgur.com/eY4ka.jpg?s=128&g=1   10567606
# 2          0  https://www.gravatar.com/avatar/720e20205122c5...    9501631
# 3          0  https://www.gravatar.com/avatar/0f8c4bde3d8f25...   10709837
# 4          0  https://www.gravatar.com/avatar/af088558cd81c5...    7969290

# %% [markdown]
# ### **TODO**: Drop Duplicates
# Look for and drop any duplicates in all 3 of the tables (if they exist). Use Pandas to do this. If you find duplicates, you will need to rewrite the table.
#
# <div style="background-color:lemonchiffon; border:1px solid; padding:5px; margin:5px; font-weight:bold"><font color="crimson">
# TODO: Enter code in the following cells.
#     </font></div>

# %%
#Rows preduplicate check for rows in comments
comments
# Out:
#            Id  PostId  Score  \
# 0      723182  385124      0
# 1      723183  385124      3
# 2      723186  385137      0
# 3      723187  385137      0
# 4      723188  385134      0
# ...       ...     ...    ...
# 49995  791747  424214      1
# 49996  791748  424201      0
# 49997  791749  203687      0
# 49998  791752  137072      0
# 49999  791753  137057      0
#
#                                                     Text         CreationDate  \
# 0      @BenBolker I don't understand. The fit cannot ...  2019-01-01 00:06:39
# 1      You can't add *less* than (`-min(y)`), but you...  2019-01-01 00:09:22
# 2      nice. If you felt like doing the work it would...  2019-01-01 00:32:11
# 3      i.e. `emdbook::curve3d(-sum(dnbinom(y,mu=mu,si...  2019-01-01 00:40:36
# 4      Don't you mean "so variance should be $\sigma^...  2019-01-01 00:41:28
# ...                                                  ...                  ...
# 49995  Agreed. I probably should have done more than ...  2019-08-29 18:59:33
# 49996  Of course cost parameter exists on other ml al...  2019-08-29 19:05:37
# 49997  What's maybe not quite clear from that linked ...  2019-08-29 19:06:35
# 49998  GLMs are fit using iteratively reweighted leas...  2019-08-29 19:25:35
# 49999  GLMs are fit using iteratively reweighted leas...  2019-08-29 19:26:24
#
#        UserId
# 0       78575
# 1        2126
# 2        2126
# 3        2126
# 4      112141
# ...       ...
# 49995   85665
# 49996   35291
# 49997   27340
# 49998   27340
# 49999   27340
#
# [50000 rows x 6 columns]

# %%
# Duplicate rows in comments

duplicate_rows_comments = comments[comments.duplicated(subset=["Id"],keep=False)]
duplicate_rows_comments["Id"].value_counts()
duplicate_rows_comments.head()
#No duplicates in comments for Id in the comments section
#Use a print function to show the rows and columns (before and after)
# Out:
# Empty DataFrame
# Columns: [Id, PostId, Score, Text, CreationDate, UserId]
# Index: []

# %%
#Rows preduplicate in posts
posts
# Out:
#            Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0      423497           1            423511         0  2019-08-24 09:39:31
# 1      423498           1                 0         0  2019-08-24 09:47:42
# 2      423499           1                 0         0  2019-08-24 09:48:26
# 3      423500           2                 0    215865  2019-08-24 09:57:01
# 4      423502           2                 0    423286  2019-08-24 10:44:52
# ...       ...         ...               ...       ...                  ...
# 42229  438739           2                 0    270897  2019-12-01 03:52:33
# 42230  438740           2                 0     61144  2019-12-01 04:26:19
# 42231  438741           1                 0         0  2019-12-01 05:00:39
# 42232  438742           2                 0    438698  2019-12-01 05:02:44
# 42233  438743           2                 0     89809  2019-12-01 05:07:09
#
#        Score  ViewCount                                               Body  \
# 0          2         68  <p>From wikipedia <a href="https://en.wikipedi...
# 1          1         24  <p>I am currently doing local sensitivity anal...
# 2          1         56  <p>I'm an honours student in psychology doing ...
# 3          0          0  <p>Maybe you can look this <a href="https://me...
# 4          3          0  <blockquote>\n  <p>Q1) Is my approach valid?</...
# ...      ...        ...                                                ...
# 42229      0          0  <p>The purpose of the null is to convert a pro...
# 42230      0          0  <p>Related question:</p>\n\n<p>If I have the m...
# 42231      0          3  <p>I am interested in model selection and wond...
# 42232      0          0  <p>I would vote for "deterministic algorithms"...
# 42233      0          0  <p>You might as well use scale-invariant clust...
#
#        OwnerUserId OwnerDisplayName  ...  LastEditorDisplayName  \
# 0            64552             None  ...                   None
# 1            87231             None  ...                   None
# 2           257207             None  ...                   None
# 3           106606             None  ...                   None
# 4           220643             None  ...                   None
# ...            ...              ...  ...                    ...
# 42229       140300             None  ...                   None
# 42230       267322             None  ...                   None
# 42231       206102             None  ...                   None
# 42232       133755             None  ...                   None
# 42233       241137             None  ...                   None
#
#               LastEditDate     LastActivityDate  \
# 0                     None  2019-08-24 11:38:54
# 1      2019-09-06 12:52:32  2019-09-06 12:52:32
# 2                     None  2019-08-25 08:54:17
# 3                     None  2019-08-24 09:57:01
# 4      2019-08-24 12:13:46  2019-08-24 12:13:46
# ...                    ...                  ...
# 42229                 None  2019-12-01 03:52:33
# 42230                 None  2019-12-01 04:26:19
# 42231                 None  2019-12-01 05:00:39
# 42232                 None  2019-12-01 05:02:44
# 42233                 None  2019-12-01 05:07:09
#
#                                                    Title  \
# 0      When are biased estimators with lower MSE pref...
# 1      How to interpret the result from local sensiti...
# 2          Power Analysis in G-Power - Mixed Model Anova
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 42229                                               None
# 42230                                               None
# 42231  Can I do model selection comparing model compu...
# 42232                                               None
# 42233                                               None
#
#                                      Tags AnswerCount  CommentCount  \
# 0         <bias><unbiased-estimator><mse>           1             0
# 1      <sensitivity-analysis><elasticity>           1             0
# 2                         <anova><gpower>           2             0
# 3                                    None           0             0
# 4                                    None           0             1
# ...                                   ...         ...           ...
# 42229                                None           0             0
# 42230                                None           0             0
# 42231           <anova><mixed-model><aic>           0             0
# 42232                                None           0             0
# 42233                                None           0             0
#
#        FavoriteCount           ClosedDate CommunityOwnedDate
# 0                  1  2019-08-25 10:25:24               None
# 1                  0                 None               None
# 2                  0                 None               None
# 3                  0                 None               None
# 4                  0                 None               None
# ...              ...                  ...                ...
# 42229              0                 None               None
# 42230              0                 None               None
# 42231              0                 None               None
# 42232              0                 None               None
# 42233              0                 None               None
#
# [42234 rows x 21 columns]

# %%
# Duplicates in posts
#Use a print function to show the rows and columns (before and after)

#No duplicates in the duplicates for posts

duplicate_rows_posts = posts[posts.duplicated(subset=["Id"],keep=False)]
duplicate_rows_posts["Id"].value_counts()
duplicate_rows_posts
# Out:
# Empty DataFrame
# Columns: [Id, PostTypeId, AcceptedAnswerId, ParentId, CreationDate, Score, ViewCount, Body, OwnerUserId, OwnerDisplayName, LastEditorUserId, LastEditorDisplayName, LastEditDate, LastActivityDate, Title, Tags, AnswerCount, CommentCount, FavoriteCount, ClosedDate, CommunityOwnedDate]
# Index: []
#
# [0 rows x 21 columns]

# %%
#Rows preduplicates in users
users
# Out:
#            Id  Reputation         CreationDate         DisplayName  \
# 0      157607          31  2017-04-17 14:50:42          user157607
# 1      157656         101  2017-04-17 20:08:20          user102859
# 2      157704         133  2017-04-18 05:10:47              jupiar
# 3      157709         155  2017-04-18 06:39:18              farmer
# 4      157755         101  2017-04-18 12:56:17              Miki P
# ...       ...         ...                  ...                 ...
# 18407  157530         101  2017-04-16 22:44:35            Narfanar
# 18408  157574         161  2017-04-17 08:53:48                 Jan
# 18409  157575         461  2017-04-17 08:58:30       Jeremy Voisey
# 18410  157584           1  2017-04-17 10:48:14  Siyabonga Mbonambi
# 18411  157592          11  2017-04-17 12:04:35         BloodThirst
#
#             LastAccessDate              WebsiteUrl         Location  \
# 0      2019-07-23 16:44:08                    None             None
# 1      2019-06-26 13:42:13                    None             None
# 2      2019-11-25 13:32:27                    None  Shanghai, China
# 3      2019-02-17 19:44:24                    None             None
# 4      2019-08-12 17:02:21                    None             None
# ...                    ...                     ...              ...
# 18407  2019-11-29 12:50:02                    None             None
# 18408  2019-07-14 08:46:32                    None             None
# 18409  2019-11-22 05:29:36  http://www.jvoisey.com           Cyprus
# 18410  2019-06-03 08:59:00                    None             None
# 18411  2019-08-07 20:58:14                    None             None
#
#                                                  AboutMe  Views  UpVotes  \
# 0                                                   None      0        0
# 1                                                   None      3        0
# 2      <p>Originally from the U.K, I have an Undergra...      1        1
# 3                                                   None     16        0
# 4                                                   None      1        9
# ...                                                  ...    ...      ...
# 18407                                               None      1       17
# 18408                                               None     15        1
# 18409  <p>I work for a small school, where I maintain...     47       10
# 18410                                               None      1        0
# 18411                                               None      0        0
#
#        DownVotes                                    ProfileImageUrl  AccountId
# 0              0  https://www.gravatar.com/avatar/2efb161849efa4...   10705183
# 1              0      https://i.stack.imgur.com/eY4ka.jpg?s=128&g=1   10567606
# 2              0  https://www.gravatar.com/avatar/720e20205122c5...    9501631
# 3              0  https://www.gravatar.com/avatar/0f8c4bde3d8f25...   10709837
# 4              0  https://www.gravatar.com/avatar/af088558cd81c5...    7969290
# ...          ...                                                ...        ...
# 18407          0      https://i.stack.imgur.com/QtTmm.png?s=128&g=1    1071965
# 18408          0  https://www.gravatar.com/avatar/3c2b2c7b445c04...    5145151
# 18409          0      https://i.stack.imgur.com/zCfd5.jpg?s=128&g=1   10485220
# 18410          0  https://www.gravatar.com/avatar/cd488b3037badd...   10355063
# 18411          0  https://www.gravatar.com/avatar/74fe3ffa031ba9...    9762793
#
# [18412 rows x 13 columns]

# %%
# Duplicates
#Use a print function to show the rows and columns (before and after)

#No duplicates in the users part

duplicate_rows_users= users[users.duplicated(subset=["Id"],keep=False)]
duplicate_rows_users["Id"].value_counts()
duplicate_rows_users
# Out:
# Empty DataFrame
# Columns: [Id, Reputation, CreationDate, DisplayName, LastAccessDate, WebsiteUrl, Location, AboutMe, Views, UpVotes, DownVotes, ProfileImageUrl, AccountId]
# Index: []

# %% [markdown]
# ## Review the Data
#
# Spend some time reviewing the data.  Understand what data we have, think about how that data can be used to assist in the initiative of understanding how ChatData is used in the real world.  Is the data organised in a way that would lend itself to being manged in a relational database?  How would the different tables be connected?  What are the primary and foreign keys?  Would this give you a 3NF model?
#
# Also think about security and ethics.  Is there personal data in here?  Could individuals be identified through this data?  It it ethical to use the data in this way?  You will be asked to comment on these questions later!
#
# Use the code below to help you.

# %%
users.columns #How is the data useful

#Managed in relational database?
#Tables be connected
#Identified through?
#Ethics
# Out:
# Index(['Id', 'Reputation', 'CreationDate', 'DisplayName', 'LastAccessDate',
#        'WebsiteUrl', 'Location', 'AboutMe', 'Views', 'UpVotes', 'DownVotes',
#        'ProfileImageUrl', 'AccountId'],
#       dtype='object')

# %%
users.head()
# Out:
#        Id  Reputation         CreationDate DisplayName       LastAccessDate  \
# 0  157607          31  2017-04-17 14:50:42  user157607  2019-07-23 16:44:08
# 1  157656         101  2017-04-17 20:08:20  user102859  2019-06-26 13:42:13
# 2  157704         133  2017-04-18 05:10:47      jupiar  2019-11-25 13:32:27
# 3  157709         155  2017-04-18 06:39:18      farmer  2019-02-17 19:44:24
# 4  157755         101  2017-04-18 12:56:17      Miki P  2019-08-12 17:02:21
#
#   WebsiteUrl         Location  \
# 0       None             None
# 1       None             None
# 2       None  Shanghai, China
# 3       None             None
# 4       None             None
#
#                                              AboutMe  Views  UpVotes  \
# 0                                               None      0        0
# 1                                               None      3        0
# 2  <p>Originally from the U.K, I have an Undergra...      1        1
# 3                                               None     16        0
# 4                                               None      1        9
#
#    DownVotes                                    ProfileImageUrl  AccountId
# 0          0  https://www.gravatar.com/avatar/2efb161849efa4...   10705183
# 1          0      https://i.stack.imgur.com/eY4ka.jpg?s=128&g=1   10567606
# 2          0  https://www.gravatar.com/avatar/720e20205122c5...    9501631
# 3          0  https://www.gravatar.com/avatar/0f8c4bde3d8f25...   10709837
# 4          0  https://www.gravatar.com/avatar/af088558cd81c5...    7969290

# %%
comments.columns
# Out:
# Index(['Id', 'PostId', 'Score', 'Text', 'CreationDate', 'UserId'], dtype='object')

# %%
comments.head()
# Out:
#        Id  PostId  Score                                               Text  \
# 0  723182  385124      0  @BenBolker I don't understand. The fit cannot ...
# 1  723183  385124      3  You can't add *less* than (`-min(y)`), but you...
# 2  723186  385137      0  nice. If you felt like doing the work it would...
# 3  723187  385137      0  i.e. `emdbook::curve3d(-sum(dnbinom(y,mu=mu,si...
# 4  723188  385134      0  Don't you mean "so variance should be $\sigma^...
#
#           CreationDate  UserId
# 0  2019-01-01 00:06:39   78575
# 1  2019-01-01 00:09:22    2126
# 2  2019-01-01 00:32:11    2126
# 3  2019-01-01 00:40:36    2126
# 4  2019-01-01 00:41:28  112141

# %%
posts.columns
# Out:
# Index(['Id', 'PostTypeId', 'AcceptedAnswerId', 'ParentId', 'CreationDate',
#        'Score', 'ViewCount', 'Body', 'OwnerUserId', 'OwnerDisplayName',
#        'LastEditorUserId', 'LastEditorDisplayName', 'LastEditDate',
#        'LastActivityDate', 'Title', 'Tags', 'AnswerCount', 'CommentCount',
#        'FavoriteCount', 'ClosedDate', 'CommunityOwnedDate'],
#       dtype='object')

# %%
posts.head()
# Out:
#        Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  Score  \
# 0  423497           1            423511         0  2019-08-24 09:39:31      2
# 1  423498           1                 0         0  2019-08-24 09:47:42      1
# 2  423499           1                 0         0  2019-08-24 09:48:26      1
# 3  423500           2                 0    215865  2019-08-24 09:57:01      0
# 4  423502           2                 0    423286  2019-08-24 10:44:52      3
#
#    ViewCount                                               Body  OwnerUserId  \
# 0         68  <p>From wikipedia <a href="https://en.wikipedi...        64552
# 1         24  <p>I am currently doing local sensitivity anal...        87231
# 2         56  <p>I'm an honours student in psychology doing ...       257207
# 3          0  <p>Maybe you can look this <a href="https://me...       106606
# 4          0  <blockquote>\n  <p>Q1) Is my approach valid?</...       220643
#
#   OwnerDisplayName  ...  LastEditorDisplayName         LastEditDate  \
# 0             None  ...                   None                 None
# 1             None  ...                   None  2019-09-06 12:52:32
# 2             None  ...                   None                 None
# 3             None  ...                   None                 None
# 4             None  ...                   None  2019-08-24 12:13:46
#
#       LastActivityDate                                              Title  \
# 0  2019-08-24 11:38:54  When are biased estimators with lower MSE pref...
# 1  2019-09-06 12:52:32  How to interpret the result from local sensiti...
# 2  2019-08-25 08:54:17      Power Analysis in G-Power - Mixed Model Anova
# 3  2019-08-24 09:57:01                                               None
# 4  2019-08-24 12:13:46                                               None
#
#                                  Tags AnswerCount  CommentCount  \
# 0     <bias><unbiased-estimator><mse>           1             0
# 1  <sensitivity-analysis><elasticity>           1             0
# 2                     <anova><gpower>           2             0
# 3                                None           0             0
# 4                                None           0             1
#
#    FavoriteCount           ClosedDate CommunityOwnedDate
# 0              1  2019-08-25 10:25:24               None
# 1              0                 None               None
# 2              0                 None               None
# 3              0                 None               None
# 4              0                 None               None
#
# [5 rows x 21 columns]

# %% [markdown]
# # Working with Sqlite and SQL Magic
# In this section let's spend a little time understanding a bit more about how we can work with Sqlite within Jupyter.
#
# Let's look at 2 ways to query the sqlite database: using SQL Magic or using Pandas.  Either way is fine for this project.

# %% [markdown]
# ## Writing queries with SQL Magic
#
# You will now need to write some queries to get answers to the questions in the requirements.
#
# For single-line queries, start the cell with `%sql` and simply enter your query:

# %%
# This is an example
# %sql SELECT COUNT(*) FROM comments

#50,000 total in count shown for comments table
# Out:
#  * sqlite:///chatdata.db
# Done.
# [(50000,)]

# %% [markdown]
# For multi line sql statements use `%%sql` as follows. This tells Jupyter that *everything* in this cell should be interpreted as sql. So, NO comments other statements are allowed:

# %%
# %%sql
# SELECT Id, PostId, Score, Text
#     FROM comments
#         LIMIT 5
# Out:
#  * sqlite:///chatdata.db
# Done.
# [(723182, 385124, 0, '@BenBolker I don\'t understand. The fit cannot be done for the negative $y$. So intuitively I\'d think that in order to retain the relativity of the  ... (24 characters truncated) ... rror" or "flip" it to the positive axis? Would it be possible to adjust every point individually? Basically e.g. take $abs(y_i)$ instead of minimums.'),
#  (723183, 385124, 3, "You can't add *less* than (`-min(y)`), but you could add *more*. I'm going to stop answering now sorry, because **judging what the 'best' approach is ... (60 characters truncated) ...  of the analysis, why you need to fit an exponential, your level of computational and statistical sophistication and that of your audience, etc. ...)"),
#  (723186, 385137, 0, 'nice. If you felt like doing the work it would be nice to generate an image/contour plot of log-likelihood as a function of (mu, theta) and show the lines corresponding to the two `size` values .'),
#  (723187, 385137, 0, 'i.e. `emdbook::curve3d(-sum(dnbinom(y,mu=mu,size=size,log=TRUE)),\n                 xlim=c(2,5),ylim=c(0.2,0.5),\n                 varnames=c("mu","s ... (57 characters truncated) ... ,col="red")\nabline(h=fit.what$theta,col="blue")\n` ... although doesn\'t look this is actually the answer - mu-hat is independent of theta-hat ... ?'),
#  (723188, 385134, 0, 'Don\'t you mean "so variance should be $\\sigma^2/(n\\mu^2)$"')]

# %% [markdown]
# ## Writing queries with Pandas
# Another way to write queries is to use pandas:

# %%
sql = """
SELECT Id, PostId, Score, Text
    FROM comments
        LIMIT 5
        """
result = pd.read_sql(sql, con)
result
# Out:
#        Id  PostId  Score                                               Text
# 0  723182  385124      0  @BenBolker I don't understand. The fit cannot ...
# 1  723183  385124      3  You can't add *less* than (`-min(y)`), but you...
# 2  723186  385137      0  nice. If you felt like doing the work it would...
# 3  723187  385137      0  i.e. `emdbook::curve3d(-sum(dnbinom(y,mu=mu,si...
# 4  723188  385134      0  Don't you mean "so variance should be $\sigma^...

# %% [markdown]
# # Creating Tables with Referential Integrity

# %% [markdown]
# When we loaded the csv files into Sqlite database tables, Sqlite created the tables for us behind the scenes. Let's inspect this a bit more.
#
# We can see how Sqlite created the tables by querying the `sqlite_master` table, which Sqlite uses to keep track of what objects have been created in the database:

# %%
# %%sql
# select sql from sqlite_master
# Out:
#  * sqlite:///chatdata.db
# Done.
# [('CREATE TABLE "comments" (\n"Id" INTEGER,\n  "PostId" INTEGER,\n  "Score" INTEGER,\n  "Text" TEXT,\n  "CreationDate" TEXT,\n  "UserId" INTEGER\n)',),
#  ('CREATE TABLE "posts" (\n"Id" INTEGER,\n  "PostTypeId" INTEGER,\n  "AcceptedAnswerId" INTEGER,\n  "ParentId" INTEGER,\n  "CreationDate" TEXT,\n  "Scor ... (240 characters truncated) ...   "Tags" TEXT,\n  "AnswerCount" INTEGER,\n  "CommentCount" INTEGER,\n  "FavoriteCount" INTEGER,\n  "ClosedDate" TEXT,\n  "CommunityOwnedDate" TEXT\n)',),
#  ('CREATE TABLE "users" (\n"Id" INTEGER,\n  "Reputation" INTEGER,\n  "CreationDate" TEXT,\n  "DisplayName" TEXT,\n  "LastAccessDate" TEXT,\n  "WebsiteUr ... (17 characters truncated) ... tion" TEXT,\n  "AboutMe" TEXT,\n  "Views" INTEGER,\n  "UpVotes" INTEGER,\n  "DownVotes" INTEGER,\n  "ProfileImageUrl" TEXT,\n  "AccountId" INTEGER\n)',)]

# %% [markdown]
# The above results show the `CREATE TABLE` statements that could be used by Sqlite to recreate the tables with the exact same structure.
#
# The problem with the CREATE TABLE statements above is that they don't enforce **referential integrity**.  In other words, they don't ensure that every UserId and PostId in the comments table refers to an actual UserId and PostId in the users and posts tables.  At the moment. we can insert any old number here, and even have multiple users with the same Id!  One of the advantages of working with relational databases is that they can enforce the correct uniqueness and relationships in the data, but at the moment we are not using that feature.  So let's fix that...
#
# First, let's drop the original tables:

# %%
# %%sql
# DROP TABLE comments;
# DROP TABLE users;
# DROP TABLE posts;
# Out:
#  * sqlite:///chatdata.db
# Done.
# Done.
# Done.
# []

# %% [markdown]
# Prove that this worked by selecting the names of the tables back.  We should have no tables:

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table'
#     ORDER BY name
# Out:
#  * sqlite:///chatdata.db
# Done.
# []

# %% [markdown]
# In Sqlite we need to enable the enforcement of foreign key constraints:

# %%
# %%sql
# PRAGMA foreign_keys=ON;
# Out:
#  * sqlite:///chatdata.db
# Done.
# []

# %% [markdown]
# Now recreate the users table with a **primary key constraint** by copying the CREATE TABLE statement from above and adding the NOT NULL PRIMARY KEY clause to the Id:

# %%
# %%sql
# CREATE TABLE "users" (
# "Id" INTEGER NOT NULL PRIMARY KEY,
# "Reputation" INTEGER,
# "CreationDate" TEXT,
# "DisplayName" TEXT,
# "LastAccessDate" TEXT,
# "WebsiteUrl" TEXT,
# "Location" TEXT,
# "AboutMe" TEXT,
# "Views" INTEGER,
# "UpVotes" INTEGER,
# "DownVotes" INTEGER,
# "ProfileImageUrl" TEXT,
# "AccountId" INTEGER
# );
# Out:
#  * sqlite:///chatdata.db
# Done.
# []

# %% [markdown]
# Now do the same for the posts table:
#
# <div style="background-color:lemonchiffon; border:1px solid; padding:5px; margin:5px; font-weight:bold"><font color="crimson">
# TODO: Complete the following code cell
#     </font></div>

# %%
# Run the CREATE TABLE statement for the posts table, including the primary key constraint
# %%sql
CREATE TABLE "posts" (
"Id" INTEGER NOT NULL PRIMARY KEY,
"PostTypeId" INTEGER,
"AcceptedAnswerId" INTEGER,
"ParentId" INTEGER,
"CreationDate" TEXT,
"Score" INTEGER,
"ViewCount" INTEGER,
"Body" TEXT,
"OwnerUserId" INTEGER,
"OwnerDisplayName" TEXT,
"LastEditorUserId" INTEGER,
"LastEditorDisplayName" TEXT,
"LastEditDate" TEXT,
"LastActivityDate" TEXT,
"Title" TEXT,
"Tags" TEXT,
"AnswerCount" INTEGER,
"CommentCount" INTEGER,
"FavoriteCount" INTEGER,
"ClosedDate" TEXT,
"CommunityOwnedDate" TEXT
);
# Out:
#  * sqlite:///chatdata.db
# Done.
# []

# %% [markdown]
# Now for the comments table.  We need to add the primary key constraint on the id here as we did for users and posts, but we also need to add FOREIGN KEY constraints on the UserId and PostId. Read the documentation here and find our how to do that: https://www.sqlite.org/foreignkeys.html.  Then create the comments table with the correct constraints:
#
# <div style="background-color:lemonchiffon; border:1px solid; padding:5px; margin:5px; font-weight:bold"><font color="crimson">
# TODO: Complete the following code cell
#     </font></div>

# %%
# Run the CREATE TABLE statement for the comments table, including the primary key constraint and the 2 foreign key constraints #Users ID and #Post ID
# %%sql
CREATE TABLE "comments" (
"Id" INTEGER NOT NULL PRIMARY KEY,
"PostId" INTEGER,
"Score" INTEGER,
"Text" TEXT,
"CreationDate" TEXT,
"UserId" INTEGER,
FOREIGN KEY("PostID") REFERENCES posts("Id"),
FOREIGN KEY("UserID") REFERENCES users("Id")
);
# Out:
#  * sqlite:///chatdata.db
# Done.
# []

# %% [markdown]
# Now we can re-insert the data into these constrained tables.  First users:

# %%
# Insert data into the new users table
users.to_sql('users', con, if_exists='append', index=False)
# Out:
# 18412

# %% [markdown]
# Now posts:
#
# <div style="background-color:lemonchiffon; border:1px solid; padding:5px; margin:5px; font-weight:bold"><font color="crimson">
# TODO: Complete the following code cell
#     </font></div>

# %%
# Insert data into the new posts table
posts.to_sql('posts', con, if_exists='append', index=False)
# Out:
# 42234

# %% [markdown]
# Finally comments, which references the users and posts tables:
#
# <div style="background-color:lemonchiffon; border:1px solid; padding:5px; margin:5px; font-weight:bold"><font color="crimson">
# TODO: Complete the following code cell
#     </font></div>

# %%
# Insert data into the new comments table
comments.to_sql('comments', con, if_exists='append', index=False)
# Out:
# 50000

# %% [markdown]
# Now check that we have the 3 new table definitions in Sqlite:

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table'
#     ORDER BY name
# Out:
#  * sqlite:///chatdata.db
# Done.
# [('comments',), ('posts',), ('users',)]

# %% [markdown]
# We now have all the data in tables in Sqlite and the tables will enforce the referential integrity.

# %% [markdown]
# # Example Query and Pattern for Tasks 2 and 3
#
# As you work through the next tasks, you will need to:
#
# 1. Prepare the Sqlite query to answer the question
# 2. Test it
# 3. Insert it into the `queries` table, so we have a record of it for others.
#
# This is the process that we want you to follow for this project while completing it.

# %% [markdown]
# Let's see an example of this by answering the following question:
#
# **Which 5 users have viewed the most times and what is the sum of those views per user?**
#
# ## Prepare the Sqlite query
#
# First, let's write the query:

# %%
sql = """
SELECT Id, SUM(Views) AS TotalViews
    FROM Users
        GROUP BY Id
            ORDER BY TotalViews DESC
                LIMIT 5
                """
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#      Id  TotalViews
# 0   919       85180
# 1  4253       35119
# 2   805       34637
# 3  7290       32639
# 4  3277       29255

# %% [markdown]
# ## Test the query
# You can optionally prove the query worked by performing the same query in Pandas:

# %%
results = users.groupby(['Id']).sum().sort_values('Views', ascending = False)[:5]
results['Views']
# Out:
# <ipython-input-179-7b2c47bab8fa>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   results = users.groupby(['Id']).sum().sort_values('Views', ascending = False)[:5]
# Id
# 919     85180
# 4253    35119
# 805     34637
# 7290    32639
# 3277    29255
# Name: Views, dtype: int64

# %% [markdown]
# ## Insert the query into the `queries` table
# Now we need to put this query into the `queries` table in sqlite. Remember we want these queries to be accessible to everybody that should have access to them. We do not want people writing and rewriting the same queires over and over again. The easiest thing to do is create a dictionary with the values and insert these into the queries table.  Note that the values are provided as lists as we are inserting a list of values (i.e. a number of rows) into the table.  In this case the number of rows is 1, so we have lists of 1 item.
#
# So here, we have a column called 'task' with a list of values, a column called 'action' with a list of values, etc.

# %%
query_dict = {
              'task': ['Single Table Queries'],
              'action': ['Which 5 users have viewed the most times and what is the sum of those views per user?'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Single Table Queries'],
#  'action': ['Which 5 users have viewed the most times and what is the sum of those views per user?'],
#  'query': ['\nSELECT Id, SUM(Views) AS TotalViews\n    FROM Users\n        GROUP BY Id\n            ORDER BY TotalViews DESC\n                LIMIT 5\n                ']}

# %% [markdown]
# Now that you have the data structure (query_dict) containing the data, create a pandas dataframe that holds those values:

# %%
queries = pd.DataFrame(query_dict)
queries
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...

# %% [markdown]
# Now load that pandas dataframe (queries) into the sqlite table called queries. In this case, you use append NOT replace. You will be adding to this tables as you go thru this project.

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...

# %% [markdown]
# It is likely that as you iterate thru this notebook you will create some duplicate entries in the query table. Not a big deal. Just tell sql or pandas (much easier in pandas) to drop the duplicates! If you drop the duplicates in Pandas you will have to write the entire dataframe back to sqlite. Otherwise it is changed in memory in Pandas but NOT in sqlite on the disk drive (or SDD). Just do this drop at the end of this notebook so that you are not constantly dealing with this.

# %% [markdown]
# So, to summarise, as you go through the following tasks you need to:
#
# - answer the question in sql
# - prove it in pandas (if you want to)
# - put the query into the queries table

# %% [markdown]
# # Task 1 (continued): Insert the CREATE TABLE Statements into the `queries` Table
#
# Now that we understand how to populate the `queries` table, let's insert the CREATE TABLE statements into it.  First let's define a function to help us insert into the queries table:

# %%
# Define a function that will insert into the queries table
def store_query(task, action, query):
    query_dict = {
                  'task': [task],
                  'action': [action],
                  'query': [query]
                 }

    # put query into the query_dict
    queries = pd.DataFrame(query_dict)

    # load query into sqlite
    queries.to_sql('queries', con, if_exists='append', index=False)

# %% [markdown]
# Now we can specify the queries and call the above function to store them.  The first one is done for you.

# %%
sql = """
    CREATE TABLE "comments" (
    "Id" INTEGER,
    "PostId" INTEGER,
    "Score" INTEGER,
    "Text" TEXT,
    "CreationDate" TEXT,
    "UserId" INTEGER
    )
    """
store_query("Task 1", "Create table comments", sql)

# %% [markdown]
# Let's prove it works by selecting back from the queries table:

# %%
# Prove it works
# %sql SELECT * FROM queries
# Out:
#  * sqlite:///chatdata.db
# Done.
# [('Single Table Queries', 'Which 5 users have viewed the most times and what is the sum of those views per user?', '\nSELECT Id, SUM(Views) AS TotalViews\n    FROM Users\n        GROUP BY Id\n            ORDER BY TotalViews DESC\n                LIMIT 5\n                '),
#  ('Task 1', 'Create table comments', '\n    CREATE TABLE "comments" (\n    "Id" INTEGER,\n    "PostId" INTEGER,\n    "Score" INTEGER,\n    "Text" TEXT,\n    "CreationDate" TEXT,\n    "UserId" INTEGER\n    )\n    ')]

# %% [markdown]
# ## Insert the other CREATE TABLE statements into the `queries` table.
# Follow the above pattern to complete these code cells:
#
# <div style="background-color:lemonchiffon; border:1px solid; padding:5px; margin:5px; font-weight:bold"><font color="crimson">
# TODO: Complete the following code cells
#     </font></div>

# %%
# Define a function that will insert into the queries table
def store_query(task, action, query):
    query_dict = {
                  'task': [task],
                  'action': [action],
                  'query': [query]
                 }

    # put query into the query_dict
    queries = pd.DataFrame(query_dict)

    # load query into sqlite
    queries.to_sql('queries', con, if_exists='append', index=False)

# %%
sql = """
CREATE TABLE "posts" (
"Id" INTEGER,
"PostTypeId" INTEGER,
"AcceptedAnswerId" INTEGER,
"ParentId" INTEGER,
"CreationDate" TEXT,
"Score" INTEGER,
"ViewCount" INTEGER,
"Body" TEXT,
"OwnerUserId" INTEGER,
"OwnerDisplayName" TEXT,
"LastEditorUserId" INTEGER,
"LastEditorDisplayName" TEXT,
"LastEditDate" TEXT,
"LastActivityDate" TEXT,
"Title" TEXT,
"Tags" TEXT,
"AnswerCount" INTEGER,
"CommentCount" INTEGER,
"FavoriteCount" INTEGER,
"ClosedDate" TEXT,
"CommunityOwnedDate" TEXT
)
"""
store_query("Task 1", "Create table posts", sql)

# %%
# Prove it works
# %sql SELECT * FROM queries
# Out:
#  * sqlite:///chatdata.db
# Done.
# [('Single Table Queries', 'Which 5 users have viewed the most times and what is the sum of those views per user?', '\nSELECT Id, SUM(Views) AS TotalViews\n    FROM Users\n        GROUP BY Id\n            ORDER BY TotalViews DESC\n                LIMIT 5\n                '),
#  ('Task 1', 'Create table comments', '\n    CREATE TABLE "comments" (\n    "Id" INTEGER,\n    "PostId" INTEGER,\n    "Score" INTEGER,\n    "Text" TEXT,\n    "CreationDate" TEXT,\n    "UserId" INTEGER\n    )\n    '),
#  ('Task 1', 'Create table posts', '\nCREATE TABLE "posts" (\n"Id" INTEGER,\n"PostTypeId" INTEGER,\n"AcceptedAnswerId" INTEGER,\n"ParentId" INTEGER,\n"CreationDate" TEXT,\n"Score" INTEG ... (204 characters truncated) ... e" TEXT,\n"Tags" TEXT,\n"AnswerCount" INTEGER,\n"CommentCount" INTEGER,\n"FavoriteCount" INTEGER,\n"ClosedDate" TEXT,\n"CommunityOwnedDate" TEXT\n)\n')]

# %%
# Define a function that will insert into the queries table
def store_query(task, action, query):
    query_dict = {
                  'task': [task],
                  'action': [action],
                  'query': [query]
                 }

    # put query into the query_dict
    queries = pd.DataFrame(query_dict)

    # load query into sqlite
    queries.to_sql('queries', con, if_exists='append', index=False)

# %%
sql = """
CREATE TABLE "users" (
"Id" INTEGER,
"Reputation" INTEGER,
"CreationDate" TEXT,
"DisplayName" TEXT,
"LastAccessDate" TEXT,
"WebsiteUrl" TEXT,
"Location" TEXT,
"AboutMe" TEXT,
"Views" INTEGER,
"UpVotes" INTEGER,
"DownVotes" INTEGER,
"ProfileImageUrl" TEXT,
"AccountId" INTEGER
)
"""
store_query("Task 1", "Create table users ", sql)

# %%
# Prove it works
# %sql SELECT * FROM queries
# Out:
#  * sqlite:///chatdata.db
# Done.
# [('Single Table Queries', 'Which 5 users have viewed the most times and what is the sum of those views per user?', '\nSELECT Id, SUM(Views) AS TotalViews\n    FROM Users\n        GROUP BY Id\n            ORDER BY TotalViews DESC\n                LIMIT 5\n                '),
#  ('Task 1', 'Create table comments', '\n    CREATE TABLE "comments" (\n    "Id" INTEGER,\n    "PostId" INTEGER,\n    "Score" INTEGER,\n    "Text" TEXT,\n    "CreationDate" TEXT,\n    "UserId" INTEGER\n    )\n    '),
#  ('Task 1', 'Create table posts', '\nCREATE TABLE "posts" (\n"Id" INTEGER,\n"PostTypeId" INTEGER,\n"AcceptedAnswerId" INTEGER,\n"ParentId" INTEGER,\n"CreationDate" TEXT,\n"Score" INTEG ... (204 characters truncated) ... e" TEXT,\n"Tags" TEXT,\n"AnswerCount" INTEGER,\n"CommentCount" INTEGER,\n"FavoriteCount" INTEGER,\n"ClosedDate" TEXT,\n"CommunityOwnedDate" TEXT\n)\n'),
#  ('Task 1', 'Create table users ', '\nCREATE TABLE "users" (\n"Id" INTEGER,\n"Reputation" INTEGER,\n"CreationDate" TEXT,\n"DisplayName" TEXT,\n"LastAccessDate" TEXT,\n"WebsiteUrl" TEXT,\n"Location" TEXT,\n"AboutMe" TEXT,\n"Views" INTEGER,\n"UpVotes" INTEGER,\n"DownVotes" INTEGER,\n"ProfileImageUrl" TEXT,\n"AccountId" INTEGER\n)\n')]

# %% [markdown]
# ## Count the Number of Rows in Each Table
# Run some queries to count the number of rows in each of the tables.  Don't forget to insert the query into the queries table.
#
# <div style="background-color:lemonchiffon; border:1px solid; padding:5px; margin:5px; font-weight:bold"><font color="crimson">
# TODO: Complete the following code cells
#     </font></div>

# %%
# Count the number of rows in the comments table
# TODO

# Assume 'comments' table is loaded into a Pandas DataFrame
comments_df = pd.read_sql_query("SELECT * FROM comments", con)
# Get the number of rows using the shape attribute
comments_df.shape[0]
comments_df
# Out:
#            Id  PostId  Score  \
# 0      723182  385124      0
# 1      723183  385124      3
# 2      723186  385137      0
# 3      723187  385137      0
# 4      723188  385134      0
# ...       ...     ...    ...
# 49995  791747  424214      1
# 49996  791748  424201      0
# 49997  791749  203687      0
# 49998  791752  137072      0
# 49999  791753  137057      0
#
#                                                     Text         CreationDate  \
# 0      @BenBolker I don't understand. The fit cannot ...  2019-01-01 00:06:39
# 1      You can't add *less* than (`-min(y)`), but you...  2019-01-01 00:09:22
# 2      nice. If you felt like doing the work it would...  2019-01-01 00:32:11
# 3      i.e. `emdbook::curve3d(-sum(dnbinom(y,mu=mu,si...  2019-01-01 00:40:36
# 4      Don't you mean "so variance should be $\sigma^...  2019-01-01 00:41:28
# ...                                                  ...                  ...
# 49995  Agreed. I probably should have done more than ...  2019-08-29 18:59:33
# 49996  Of course cost parameter exists on other ml al...  2019-08-29 19:05:37
# 49997  What's maybe not quite clear from that linked ...  2019-08-29 19:06:35
# 49998  GLMs are fit using iteratively reweighted leas...  2019-08-29 19:25:35
# 49999  GLMs are fit using iteratively reweighted leas...  2019-08-29 19:26:24
#
#        UserId
# 0       78575
# 1        2126
# 2        2126
# 3        2126
# 4      112141
# ...       ...
# 49995   85665
# 49996   35291
# 49997   27340
# 49998   27340
# 49999   27340
#
# [50000 rows x 6 columns]

# %%
# Assume 'comments' table is loaded into a Pandas DataFrame
users_df = pd.read_sql_query("SELECT * FROM users", con)

# Get the number of rows using the shape attribute
users_df.shape[0]
users_df

#18412 rows shown in table
# Out:
#            Id  Reputation         CreationDate                DisplayName  \
# 0          -1           1  2010-07-19 06:55:26                  Community
# 1           8       11189  2010-07-19 19:04:52                csgillespie
# 2          22        1085  2010-07-19 19:09:00                      radek
# 3          25       12910  2010-07-19 19:09:32            Harvey Motulsky
# 4          29        5247  2010-07-19 19:09:42                    JD Long
# ...       ...         ...                  ...                        ...
# 18407  267311          11  2019-12-01 00:41:16                     Luisda
# 18408  267315           1  2019-12-01 01:37:42                  Karing LI
# 18409  267316           1  2019-12-01 01:52:34              Shawn Preston
# 18410  267318           1  2019-12-01 03:10:07  James-Andrew R. Sarmiento
# 18411  267322           1  2019-12-01 04:22:45                   GnomGnom
#
#             LastAccessDate                                         WebsiteUrl  \
# 0      2010-07-19 06:55:26                     http://meta.stackexchange.com/
# 1      2019-11-26 13:37:20                     https://www.jumpingrivers.com/
# 2      2019-11-26 02:21:34  http://www.ispm.unibe.ch/about_us/staff/pancza...
# 3      2019-11-26 13:03:00                            http://www.graphpad.com
# 4      2019-11-18 17:43:29                                               None
# ...                    ...                                                ...
# 18407  2019-12-01 00:41:16                                               None
# 18408  2019-12-01 05:45:03                                               None
# 18409  2019-12-01 03:01:44                                               None
# 18410  2019-12-01 03:10:07                                               None
# 18411  2019-12-01 04:22:45                                               None
#
#                         Location  \
# 0             on the server farm
# 1      Newcastle, United Kingdom
# 2        Brisbane QLD, Australia
# 3                Santa Monica CA
# 4                   NYC, NY, USA
# ...                          ...
# 18407                       None
# 18408                       None
# 18409                       None
# 18410                       None
# 18411              Rockville, MD
#
#                                                  AboutMe  Views  UpVotes  \
# 0      <p>Hi, I'm not really a person.</p>\n\n<p>I'm ...      0    16988
# 1      <p>I'm a senior statistics lecturer at Newcast...   1885      635
# 2      <p>Working with data, mainly in R, mainly on (...    260     1090
# 3      <p>I am the founder and CEO of <a href="http:/...   1828      558
# 4      <p>Only slightly ashamed creator of disgusting...    982       39
# ...                                                  ...    ...      ...
# 18407                                               None      0        0
# 18408                                               None      1        0
# 18409                                               None      0        0
# 18410                                               None      1        0
# 18411  <p>Running:\nLenovo Yoga 11s\nUbuntu 14.04 LTS...      0        0
#
#        DownVotes                                    ProfileImageUrl  AccountId
# 0           7620                                               None         -1
# 1             29                                               None      70002
# 2              8  https://www.gravatar.com/avatar/7b78d24fca2c22...     124416
# 3             40                                               None     504968
# 4              2      https://i.stack.imgur.com/GiarY.jpg?s=128&g=1      17035
# ...          ...                                                ...        ...
# 18407          0  https://www.gravatar.com/avatar/c0d40402d71df4...    7293857
# 18408          0  https://lh3.googleusercontent.com/-ZzAYuCQoB4E...   17213772
# 18409          0                                               None   17213801
# 18410          0  https://graph.facebook.com/1728266520533653/pi...   14579283
# 18411          0      https://i.stack.imgur.com/t8SOe.jpg?s=128&g=1    4367681
#
# [18412 rows x 13 columns]

# %%
# Assume 'comments' table is loaded into a Pandas DataFrame
posts_df = pd.read_sql_query("SELECT * FROM posts", con)

# Get the number of rows using the shape attribute
posts_df.shape[0]
posts_df

#42234 rows
# Out:
#            Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0      385136           1                 0         0  2019-01-01 00:16:33
# 1      385137           2                 0    384932  2019-01-01 00:17:09
# 2      385138           2                 0    384678  2019-01-01 01:29:22
# 3      385139           2                 0    322831  2019-01-01 01:30:22
# 4      385141           1            385150         0  2019-01-01 02:50:26
# ...       ...         ...               ...       ...                  ...
# 42229  438739           2                 0    270897  2019-12-01 03:52:33
# 42230  438740           2                 0     61144  2019-12-01 04:26:19
# 42231  438741           1                 0         0  2019-12-01 05:00:39
# 42232  438742           2                 0    438698  2019-12-01 05:02:44
# 42233  438743           2                 0     89809  2019-12-01 05:07:09
#
#        Score  ViewCount                                               Body  \
# 0          0         89  <p>I'm currently doing A-level Further Maths A...
# 1          1          0  <p>You are forgetting that <code>glm.nb</code>...
# 2          2          0  <p>Yes, you are quite right. When we write the...
# 3          4          0  <p>Question 1 is straightforward, here <span c...
# 4          1        187  <p>Suppose we have a random sample <span class...
# ...      ...        ...                                                ...
# 42229      0          0  <p>The purpose of the null is to convert a pro...
# 42230      0          0  <p>Related question:</p>\n\n<p>If I have the m...
# 42231      0          3  <p>I am interested in model selection and wond...
# 42232      0          0  <p>I would vote for "deterministic algorithms"...
# 42233      0          0  <p>You might as well use scale-invariant clust...
#
#        OwnerUserId OwnerDisplayName  ...  LastEditorDisplayName  \
# 0           222821             None  ...                   None
# 1           129321             None  ...                   None
# 2           129321             None  ...                   None
# 3           110943             None  ...                   None
# 4           161381             None  ...                   None
# ...            ...              ...  ...                    ...
# 42229       140300             None  ...                   None
# 42230       267322             None  ...                   None
# 42231       206102             None  ...                   None
# 42232       133755             None  ...                   None
# 42233       241137             None  ...                   None
#
#               LastEditDate     LastActivityDate  \
# 0      2019-01-02 11:39:27  2019-01-02 11:39:27
# 1      2019-01-01 00:58:48  2019-01-01 00:58:48
# 2      2019-01-13 01:36:32  2019-01-13 01:36:32
# 3                     None  2019-01-01 01:30:22
# 4      2019-02-10 23:22:49  2019-02-10 23:22:49
# ...                    ...                  ...
# 42229                 None  2019-12-01 03:52:33
# 42230                 None  2019-12-01 04:26:19
# 42231                 None  2019-12-01 05:00:39
# 42232                 None  2019-12-01 05:02:44
# 42233                 None  2019-12-01 05:07:09
#
#                                                    Title  \
# 0           Difference between pooled variance equations
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4      Finding the MVUE from two independent random s...
# ...                                                  ...
# 42229                                               None
# 42230                                               None
# 42231  Can I do model selection comparing model compu...
# 42232                                               None
# 42233                                               None
#
#                                                     Tags AnswerCount  \
# 0                                    <variance><pooling>           1
# 1                                                   None           0
# 2                                                   None           0
# 3                                                   None           0
# 4      <mathematical-statistics><inference><informati...           1
# ...                                                  ...         ...
# 42229                                               None           0
# 42230                                               None           0
# 42231                          <anova><mixed-model><aic>           0
# 42232                                               None           0
# 42233                                               None           0
#
#        CommentCount  FavoriteCount  ClosedDate CommunityOwnedDate
# 0                 0              0        None               None
# 1                 2              0        None               None
# 2                 0              0        None               None
# 3                 0              0        None               None
# 4                 2              1        None               None
# ...             ...            ...         ...                ...
# 42229             0              0        None               None
# 42230             0              0        None               None
# 42231             0              0        None               None
# 42232             0              0        None               None
# 42233             0              0        None               None
#
# [42234 rows x 21 columns]

# %% [markdown]
# ## Do some Random Checks on the Data
# Let's write some queries that select 5 random rows from each table.  The queries are provided here:
#
#     select * from Comments order by random() limit 5;
#     select * from Users order by random() limit 5;
#     select * from Posts order by random() limit 5;
#
# Enter the queries into the code cells below and insert the queries into the `queries` table in the same was as you did for the CREATE TABLE statements.
#
# <div style="background-color:lemonchiffon; border:1px solid; padding:5px; margin:5px; font-weight:bold"><font color="crimson">
# TODO: Complete the following code cells
#     </font></div>

# %%
# Run the query to select 5 random rows from the posts table
posts_data = %sql SELECT * FROM posts ORDER BY RANDOM() LIMIT 5;

# Convert the result to a Pandas DataFrame
posts_df = posts_data.DataFrame()

# Display the DataFrame
posts_df
# Out:
#  * sqlite:///chatdata.db
# Done.
#        Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  Score  \
# 0  392376           1                 0         0  2019-02-13 21:55:42      3
# 1  414685           1                 0         0  2019-06-25 15:51:50      0
# 2  399164           1                 0         0  2019-03-24 15:15:25      0
# 3  429583           1                 0         0  2019-10-01 20:51:58      1
# 4  407791           1                 0         0  2019-05-11 08:20:29      0
#
#    ViewCount                                               Body  OwnerUserId  \
# 0        831  <p>I am doing research on Winsorization (and t...       237596
# 1         20  <p>I gave an intervention to a Spanish speakin...       243739
# 2         24  <p>I have four I(1) series, and the Johansen t...       242266
# 3         52  <p><strong>Background</strong>\nI've implement...       202274
# 4         14  <p>Why does the term underlined in RED converg...       225557
#
#   OwnerDisplayName  ...  LastEditorDisplayName         LastEditDate  \
# 0             None  ...                   None  2019-10-29 12:48:07
# 1             None  ...                   None  2019-06-25 16:01:49
# 2             None  ...                   None  2019-03-24 15:36:42
# 3             None  ...                   None  2019-10-02 00:29:19
# 4             None  ...                   None                 None
#
#       LastActivityDate                                              Title  \
# 0  2019-10-29 12:48:07                    use and misuse of Winsorization
# 1  2019-06-25 16:01:49       Comparing two samples with pre and post each
# 2  2019-03-24 15:36:42  Can I use VAR model on I(1) series with cointe...
# 3  2019-10-02 00:29:19  Dirichlet Process Concentration Parameter - co...
# 4  2019-05-11 08:20:29                 Regression coefficient convergence
#
#                                                 Tags AnswerCount  \
# 0     <inference><robust><winsorizing><trimmed-mean>           1
# 1                     <t-test><multiple-comparisons>           0
# 2  <time-series><forecasting><var><cointegration>...           0
# 3  <bayesian><computational-statistics><dirichlet...           0
# 4            <regression><econometrics><convergence>           0
#
#    CommentCount  FavoriteCount           ClosedDate CommunityOwnedDate
# 0             2              1                 None               None
# 1             2              0                 None               None
# 2             1              0  2019-03-25 13:23:50               None
# 3             1              0                 None               None
# 4             0              0                 None               None
#
# [5 rows x 21 columns]

# %%
# Run the query to select 5 random rows from the posts comments
comments_data = %sql SELECT * FROM comments ORDER BY RANDOM() LIMIT 5;

comments_df = comments_data.DataFrame()

comments_df
#Output as a dataframe for Pandas using con through pd.read
# Out:
#  * sqlite:///chatdata.db
# Done.
#        Id  PostId  Score                                               Text  \
# 0  773206  414204      1  A DLM doesn't have to be bayesian ( see Andrew...
# 1  768799  411699      1  It may be that there's a possible argument (pe...
# 2  765540  409783      0  My solver has not omitted one of the interacti...
# 3  726987  386656      0  Well, I know one way conceptually for SEM to c...
# 4  744307  396983      0  Thank you for answering. If I understand right...
#
#           CreationDate  UserId
# 0  2019-06-22 15:38:43   64098
# 1  2019-06-05 23:02:52     805
# 2  2019-05-23 15:06:43  216852
# 3  2019-01-14 06:47:55  233718
# 4  2019-03-12 17:15:15  240744

# %%
# Run the query to select 5 random rows from the users table
users_data = %sql SELECT * FROM users ORDER BY RANDOM() LIMIT 5;

users_df = users_data.DataFrame()

users_df
# Out:
#  * sqlite:///chatdata.db
# Done.
#        Id  Reputation         CreationDate DisplayName       LastAccessDate  \
# 0   36519           3  2013-12-22 22:38:05    Benoa411  2019-11-12 20:44:06
# 1  235542           1  2019-01-27 22:56:44        Subi  2019-06-30 06:57:23
# 2  257720          11  2019-08-30 15:36:04   User00257  2019-11-28 17:15:29
# 3  192772         111  2018-01-24 23:01:56     M090009  2019-11-21 15:17:28
# 4  141275          11  2016-12-05 21:43:02    shoeburg  2019-11-27 16:31:47
#
#                                           WebsiteUrl  \
# 0  https://figshare.com/authors/Benoit_Lamarsaude...
# 1                                               None
# 2                                               None
# 3                                http://altohamy.com
# 4                                               None
#
#                           Location  \
# 0                           France
# 1                         Anywhere
# 2                             None
# 3  Abu Dhabi, United Arab Emirates
# 4                             None
#
#                                              AboutMe  Views  UpVotes  \
# 0  <p>Mechanical engineer, student in actuarial s...      0        0
# 1                                               None      2        0
# 2                                               None      0        0
# 3                                               None      6        4
# 4                                               None      0        0
#
#    DownVotes                                    ProfileImageUrl  AccountId
# 0          0      https://i.stack.imgur.com/IMCmH.jpg?s=128&g=1    2767832
# 1          0  https://www.gravatar.com/avatar/52ae87e6b5a989...    2871714
# 2          0  https://www.gravatar.com/avatar/dea05c27c789ed...   16605628
# 3          0      https://i.stack.imgur.com/PSYnB.jpg?s=128&g=1    2181623
# 4          0  https://www.gravatar.com/avatar/096be7ce003b76...    3598625

# %% [markdown]
# # Task 2: Create Single Table Queries

# %% [markdown]
# ## Lifecycle Stage: Analyze
# We can now start the analysis with our single-table queries.  First we need to create a new computed column to help with one of the queries.  The code below creates a column called LEN_BODY which is the length of the BODY text:

# %%
# %%sql
# ALTER TABLE POSTS ADD COLUMN LEN_BODY INT
# Out:
#  * sqlite:///chatdata.db
# Done.
# []

# %%
# %%sql
# UPDATE POSTS SET LEN_BODY = LENGTH(BODY)
# Out:
#  * sqlite:///chatdata.db
# 42234 rows affected.
# []

# %% [markdown]
# ### Single Table Queries
# From the Template SQL Queries there are a series of queries requested. You are responsible for coding the result. Use the pattern above to accomplish the coding objective.  Copy and paste the question (column B Action) into a markdown cell and answer the query. Use the pattern that you have been using above.
#
# <div style="background-color:lemonchiffon; border:1px solid; padding:5px; margin:5px; font-weight:bold"><font color="crimson">
# TODO: Enter your code below.  Just keep on inserting cells as you need them.
#     </font></div>

# %%
query_dict = {
              'task': ['Single Table Queries'],
              'action': ['How many posts have been created by a user that has a filled out the "AboutMe" section? '],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Single Table Queries'],
#  'action': ['How many posts have been created by a user that has a filled out the "AboutMe" section? '],
#  'query': ['\nSELECT COUNT(*) As NumPostsByUsersWithAboutMe\nFrom posts\nJOIN users ON posts.OwnerUserId= users.Id\n                ']}

# %%
queries = pd.DataFrame(query_dict)
queries
# Out:
#                    task                                             action  \
# 0  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
# How many posts have 0 comments
sql= """ SELECT commentcount, COUNT(*) AS number_of_comment_0
FROM posts
WHERE commentcount = 0;
"""
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#    CommentCount  number_of_comment_0
# 0             0                21713

# %%
query_dict = {
              'task': ['Single Table Queries'],
              'action': ['How many posts have 0 comments?'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Single Table Queries'],
#  'action': ['How many posts have 0 comments?'],
#  'query': [' SELECT commentcount, COUNT(*) AS number_of_comment_0\nFROM posts\nWHERE commentcount = 0;\n']}

# %%
# Prove it works
queries = pd.DataFrame(query_dict)
queries
# Out:
#                    task                           action  \
# 0  Single Table Queries  How many posts have 0 comments?
#
#                                                query
# 0   SELECT commentcount, COUNT(*) AS number_of_co...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
# How many posts have 1 comment
sql = """ SELECT commentcount, COUNT(*) AS number_of_comment_1
FROM posts
WHERE commentcount = 1;
"""
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#    CommentCount  number_of_comment_1
# 0             1                 6460

# %%
query_dict = {
              'task': ['Single Table Queries'],
              'action': ['How many posts have 1 comments?'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Single Table Queries'],
#  'action': ['How many posts have 1 comments?'],
#  'query': [' SELECT commentcount, COUNT(*) AS number_of_comment_1\nFROM posts\nWHERE commentcount = 1;\n']}

# %%
# Prove it works
queries = pd.DataFrame(query_dict)
queries
# Out:
#                    task                           action  \
# 0  Single Table Queries  How many posts have 1 comments?
#
#                                                query
# 0   SELECT commentcount, COUNT(*) AS number_of_co...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
sql = """ SELECT commentcount, COUNT(*) AS number_of_comment_2
FROM posts
WHERE commentcount >= 2;
"""

result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#    CommentCount  number_of_comment_2
# 0             2                14061

# %%
query_dict = {
              'task': ['Single Table Queries'],
              'action': ['How many posts have 2 comments or more?'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Single Table Queries'],
#  'action': ['How many posts have 2 comments or more?'],
#  'query': [' SELECT commentcount, COUNT(*) AS number_of_comment_2\nFROM posts\nWHERE commentcount >= 2;\n']}

# %%
# Prove it works
queries = pd.DataFrame(query_dict)
queries
# Out:
#                    task                                   action  \
# 0  Single Table Queries  How many posts have 2 comments or more?
#
#                                                query
# 0   SELECT commentcount, COUNT(*) AS number_of_co...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
sql = """ SELECT * From POSTS P
ORDER BY P.Viewcount
DESC LIMIT 5;
"""
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#        Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  Score  \
# 0  388566           1            388582         0  2019-01-22 15:16:47     56
# 1  394118           1            394128         0  2019-02-24 14:07:11     64
# 2  431370           1            431397         0  2019-10-14 11:29:21     77
# 3  398646           1            398653         0  2019-03-21 01:19:52     61
# 4  434128           1            434579         0  2019-11-01 13:07:36     73
#
#    ViewCount                                               Body  OwnerUserId  \
# 0      19542  <ul>\n<li>Statement One (S1): "One in 80 death...       228214
# 1      16317  <p>A human child at age 2 needs around 5 insta...       107213
# 2      11723  <p>It seems very counter intuitive to many peo...       262594
# 3       9850  <p>The title of the Comment in Nature <a href=...       163067
# 4       6718  <p>I am designing a one year program in data a...        14188
#
#   OwnerDisplayName  ...         LastEditDate     LastActivityDate  \
# 0             None  ...  2019-01-22 21:40:39  2019-01-24 17:09:47
# 1             None  ...  2019-02-25 22:40:22  2019-03-03 17:37:05
# 2             None  ...  2019-11-28 01:44:34  2019-11-28 01:44:34
# 3             None  ...  2019-03-22 22:14:04  2019-03-30 19:35:27
# 4             None  ...                 None  2019-11-26 00:59:15
#
#                                                Title  \
# 0  Is it wrong to rephrase "1 in 80 deaths is cau...
# 1  Why do neural networks need so many training e...
# 2  Is there a name for the phenomenon of false po...
# 3  What does "Scientists rise up against statisti...
# 4  Famous statistical wins and horror stories for...
#
#                                                 Tags AnswerCount CommentCount  \
# 0                             <interpretation><risk>           9           15
# 1                    <neural-networks><neuroscience>          12           24
# 2              <probability><terminology><intuition>           8            9
# 3          <statistical-significance><p-value><bias>          10            7
# 4  <mathematical-statistics><data-visualization><...          13            7
#
#    FavoriteCount  ClosedDate   CommunityOwnedDate LEN_BODY
# 0             15        None                 None     2270
# 1             38        None                 None      512
# 2             18        None                 None      811
# 3             34        None                 None     2148
# 4             70        None  2019-11-01 15:12:41     1172
#
# [5 rows x 22 columns]

# %%
query_dict = {
              'task': ['Single Table Queries'],
              'action': ['Find the 5 posts with the highest viewcount'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Single Table Queries'],
#  'action': ['Find the 5 posts with the highest viewcount'],
#  'query': [' SELECT * From POSTS P\nORDER BY P.Viewcount\nDESC LIMIT 5;\n']}

# %%
# Prove it works
queries = pd.DataFrame(query_dict)
queries
# Out:
#                    task                                       action  \
# 0  Single Table Queries  Find the 5 posts with the highest viewcount
#
#                                                query
# 0   SELECT * From POSTS P\nORDER BY P.Viewcount\n...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
query_dict = {
              'task': ['Single Table Queries'],
              'action': ['Find the 5 posts with the highest viewcount'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Single Table Queries'],
#  'action': ['Find the 5 posts with the highest viewcount'],
#  'query': ['SELECT * FROM queries']}

# %%
# Prove it works
queries = pd.DataFrame(query_dict)
queries
# Out:
#                    task                                       action  \
# 0  Single Table Queries  Find the 5 posts with the highest viewcount
#
#                    query
# 0  SELECT * FROM queries

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
# frequent scores on posts    To show the dataframe in the columns in df
sql = """ SELECT Score, COUNT(*) AS Frequency
FROM posts
GROUP BY Score
ORDER BY Frequency DESC, Score DESC
LIMIT 5;
"""
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#    Score  Frequency
# 0      0      19888
# 1      1      11867
# 2      2       5094
# 3      3       2228
# 4      4       1059

# %%
query_dict = {
              'task': ['Single Table Queries'],
              'action': ['What are the 5 most frequent scores on posts'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Single Table Queries'],
#  'action': ['What are the 5 most frequent scores on posts'],
#  'query': [' SELECT Score, COUNT(*) AS Frequency\nFROM posts\nGROUP BY Score\nORDER BY Frequency DESC, Score DESC\nLIMIT 5;\n']}

# %%
# Prove it works
queries = pd.DataFrame(query_dict)
queries
# Out:
#                    task                                        action  \
# 0  Single Table Queries  What are the 5 most frequent scores on posts
#
#                                                query
# 0   SELECT Score, COUNT(*) AS Frequency\nFROM pos...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
sql = """
SELECT * FROM POSTS P
ORDER BY P.SCORE
DESC LIMIT 5
"""
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#        Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  Score  \
# 0  431397           2                 0    431370  2019-10-14 14:29:36    101
# 1  394128           2                 0    394118  2019-02-24 15:44:44    100
# 2  426878           2                 0    426873  2019-09-11 23:23:31     93
# 3  388578           2                 0    388566  2019-01-22 15:48:47     80
# 4  431370           1            431397         0  2019-10-14 11:29:21     77
#
#    ViewCount                                               Body  OwnerUserId  \
# 0          0  <p>Yes there is. Generally it is termed <stron...       142976
# 1          0  <p>I caution against expecting strong resembla...        22311
# 2          0  <p><strong>tl;dr</strong> Even though this is ...       119015
# 3          0  <p>To me "1 in 80 deaths..." is by far the cle...       227039
# 4      11723  <p>It seems very counter intuitive to many peo...       262594
#
#   OwnerDisplayName  ...         LastEditDate     LastActivityDate  \
# 0             None  ...                 None  2019-10-14 14:29:36
# 1             None  ...  2019-03-03 17:37:05  2019-03-03 17:37:05
# 2             None  ...  2019-09-13 14:02:28  2019-09-13 14:02:28
# 3             None  ...                 None  2019-01-22 15:48:47
# 4             None  ...  2019-11-28 01:44:34  2019-11-28 01:44:34
#
#                                                Title  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  Is there a name for the phenomenon of false po...
#
#                                     Tags AnswerCount CommentCount  \
# 0                                   None           0            0
# 1                                   None           0           15
# 2                                   None           0            6
# 3                                   None           0           11
# 4  <probability><terminology><intuition>           8            9
#
#    FavoriteCount  ClosedDate  CommunityOwnedDate LEN_BODY
# 0              0        None                None      269
# 1              0        None                None     5829
# 2              0        None                None     4627
# 3              0        None                None      572
# 4             18        None                None      811
#
# [5 rows x 22 columns]

# %%
# Number that contains data
sql= """
SELECT COUNT(*) AS NumPostsWithTagData
FROM posts
WHERE Tags LIKE '%data%';
"""
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#    NumPostsWithTagData
# 0                 2242

# %%
query_dict = {
              'task': ['Single Table Queries'],
              'action': ['How many posts have the keyword "data" in their tags?'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Single Table Queries'],
#  'action': ['How many posts have the keyword "data" in their tags?'],
#  'query': ["\nSELECT COUNT(*) AS NumPostsWithTagData\nFROM posts\nWHERE Tags LIKE '%data%';\n"]}

# %%
# Prove it works
queries = pd.DataFrame(query_dict)
queries
# Out:
#                    task                                             action  \
# 0  Single Table Queries  How many posts have the keyword "data" in thei...
#
#                                                query
# 0  \nSELECT COUNT(*) AS NumPostsWithTagData\nFROM...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
#5 Comment Count for posts
sql= """ SELECT commentcount, COUNT(*) AS Frequency
FROM posts
GROUP BY commentcount
ORDER BY Frequency DESC, commentcount DESC
LIMIT 5;
"""
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#    CommentCount  Frequency
# 0             0      21713
# 1             1       6460
# 2             2       4966
# 3             3       3063
# 4             4       2026

# %%
query_dict = {
              'task': ['Single Table Queries'],
              'action': ['What are the 5 most frequent commentcount for posts?'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Single Table Queries'],
#  'action': ['What are the 5 most frequent commentcount for posts?'],
#  'query': [' SELECT commentcount, COUNT(*) AS Frequency\nFROM posts\nGROUP BY commentcount\nORDER BY Frequency DESC, commentcount DESC\nLIMIT 5;\n']}

# %%
# Prove it works
queries = pd.DataFrame(query_dict)
queries
# Out:
#                    task                                             action  \
# 0  Single Table Queries  What are the 5 most frequent commentcount for ...
#
#                                                query
# 0   SELECT commentcount, COUNT(*) AS Frequency\nF...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
# TODO
sql="""
SELECT AVG(reputation) AS average_reputation_amount
FROM users;
"""
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#    average_reputation_amount
# 0                 312.350912

# %%
query_dict = {
              'task': ['Single Table Queries'],
              'action': ['What is the average reputation of table users?'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Single Table Queries'],
#  'action': ['What is the average reputation of table users?'],
#  'query': ['\nSELECT AVG(reputation) AS average_reputation_amount\nFROM users;\n']}

# %%
queries = pd.DataFrame(query_dict)
queries
# Out:
#                    task                                          action  \
# 0  Single Table Queries  What is the average reputation of table users?
#
#                                                query
# 0  \nSELECT AVG(reputation) AS average_reputation...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
# Accepted Answer ID = 0
sql = """
SELECT COUNT(*) AS NumPostsAcceptedAnswerId
FROM posts
WHERE AcceptedAnswerId > 0;
"""
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#    NumPostsAcceptedAnswerId
# 0                      5341

# %%
query_dict = {
              'task': ['Single Table Queries'],
              'action': ['What are the 5 most frequent commentcount for posts?'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Single Table Queries'],
#  'action': ['What are the 5 most frequent commentcount for posts?'],
#  'query': ['\nSELECT COUNT(*) AS NumPostsAcceptedAnswerId\nFROM posts\nWHERE AcceptedAnswerId > 0;\n']}

# %%
queries = pd.DataFrame(query_dict)
queries
# Out:
#                    task                                             action  \
# 0  Single Table Queries  What are the 5 most frequent commentcount for ...
#
#                                                query
# 0  \nSELECT COUNT(*) AS NumPostsAcceptedAnswerId\...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
#Min and max for reputation of users
sql= """
SELECT MIN(Reputation) AS MinReputation,
MAX(Reputation) AS MaxReputation
FROM users;
"""
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#    MinReputation  MaxReputation
# 0              1         228662

# %%
query_dict = {
              'task': ['Single Table Queries'],
              'action': ['What are the min reputation of users?'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Single Table Queries'],
#  'action': ['What are the min reputation of users?'],
#  'query': ['\nSELECT MIN(Reputation) AS MinReputation,\nMAX(Reputation) AS MaxReputation\nFROM users;\n']}

# %%
queries = pd.DataFrame(query_dict)
queries
# Out:
#                    task                                 action  \
# 0  Single Table Queries  What are the min reputation of users?
#
#                                                query
# 0  \nSELECT MIN(Reputation) AS MinReputation,\nMA...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
#Maximum reputation of users join both as one script
sql="""
SELECT Max(Reputation) AS MaxReputation FROM users;
"""
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#    MaxReputation
# 0         228662

# %%
query_dict = {
              'task': ['Single Table Queries'],
              'action': ['What are the max reputation of users?'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Single Table Queries'],
#  'action': ['What are the max reputation of users?'],
#  'query': ['\nSELECT Max(Reputation) AS MaxReputation FROM users;\n']}

# %%
queries = pd.DataFrame(query_dict)
queries
# Out:
#                    task                                 action  \
# 0  Single Table Queries  What are the max reputation of users?
#
#                                                query
# 0  \nSELECT Max(Reputation) AS MaxReputation FROM...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
#Number for body length based on posts ordered by posts
sql= """
SELECT LENGTH(Body) AS BodyLength
FROM posts
ORDER BY ViewCount DESC
LIMIT 5;
"""
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#    BodyLength
# 0        2270
# 1         512
# 2         811
# 3        2148
# 4        1172

# %%
query_dict = {
              'task': ['Single Table Queries'],
              'action': ['What is the length of the body of 5 most viewed posts?'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Single Table Queries'],
#  'action': ['What is the length of the body of 5 most viewed posts?'],
#  'query': ['\nSELECT LENGTH(Body) AS BodyLength\nFROM posts\nORDER BY ViewCount DESC\nLIMIT 5;\n']}

# %%
queries = pd.DataFrame(query_dict)
queries
# Out:
#                    task                                             action  \
# 0  Single Table Queries  What is the length of the body of 5 most viewe...
#
#                                                query
# 0  \nSELECT LENGTH(Body) AS BodyLength\nFROM post...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
sql="""
SELECT COUNT(DISTINCT Location) AS NumberOfLocations
FROM users;
"""
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#    NumberOfLocations
# 0               1900

# %%
query_dict = {
              'task': ['Single Table Queries'],
              'action': ['How many different locations are there in the users table?'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Single Table Queries'],
#  'action': ['How many different locations are there in the users table?'],
#  'query': ['\nSELECT COUNT(DISTINCT Location) AS NumberOfLocations\nFROM users;\n']}

# %%
queries = pd.DataFrame(query_dict)
queries
# Out:
#                    task                                             action  \
# 0  Single Table Queries  How many different locations are there in the ...
#
#                                                query
# 0  \nSELECT COUNT(DISTINCT Location) AS NumberOfL...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
#Location is not null
sql="""
SELECT Location, COUNT(*) AS Frequency
FROM users
WHERE Location >0
GROUP BY Location
ORDER BY Frequency DESC
LIMIT 5;
"""
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#                  Location  Frequency
# 0                 Germany        117
# 1                   India        100
# 2           United States         69
# 3           Paris, France         66
# 4  London, United Kingdom         63

# %%
query_dict = {
              'task': ['Single Table Queries'],
              'action': ['What are the top 5 locations of users?'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Single Table Queries'],
#  'action': ['What are the top 5 locations of users?'],
#  'query': ['\nSELECT Location, COUNT(*) AS Frequency\nFROM users\nWHERE Location >0\nGROUP BY Location\nORDER BY Frequency DESC\nLIMIT 5;\n']}

# %%
queries = pd.DataFrame(query_dict)
queries
# Out:
#                    task                                  action  \
# 0  Single Table Queries  What are the top 5 locations of users?
#
#                                                query
# 0  \nSELECT Location, COUNT(*) AS Frequency\nFROM...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
#Rank days as counts from the data /Select sum view count()
sql = """
SELECT
CAST (strftime('%w', CreationDate) AS INTEGER) AS DayOfWeek,
SUM(ViewCount) AS DayCount,
ROUND(SUM(ViewCount) * 100.0 / SUM(SUM(ViewCount)) OVER (), 2) AS PercentageOfTotalViews
FROM posts
GROUP BY DayOfWeek
ORDER BY DayCount;
"""
result = pd.read_sql(sql, con)
result
# Out:
#    DayOfWeek  DayCount  PercentageOfTotalViews
# 0          6    175247                    8.89
# 1          0    234459                   11.90
# 2          5    267324                   13.56
# 3          1    311546                   15.81
# 4          2    320382                   16.26
# 5          3    330506                   16.77
# 6          4    331507                   16.82

# %%
query_dict = {
              'task': ['Single Table Queries'],
              'action': ['Rank the days of the week from highest to lowest in terms of the volume of ViewCount as a percentage?'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Single Table Queries'],
#  'action': ['Rank the days of the week from highest to lowest in terms of the volume of ViewCount as a percentage?'],
#  'query': ["\nSELECT\nCAST (strftime('%w', CreationDate) AS INTEGER) AS DayOfWeek,\nSUM(ViewCount) AS DayCount,\nROUND(SUM(ViewCount) * 100.0 / SUM(SUM(ViewCount)) OVER (), 2) AS PercentageOfTotalViews\nFROM posts\nGROUP BY DayOfWeek\nORDER BY DayCount;\n"]}

# %%
queries = pd.DataFrame(query_dict)
queries
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Rank the days of the week from highest to lowe...
#
#                                                query
# 0  \nSELECT\nCAST (strftime('%w', CreationDate) A...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
#Task 2 queries

queries
# Out:
#                     task                                             action  \
# 0   Single Table Queries  Which 5 users have viewed the most times and w...
# 1                 Task 1                              Create table comments
# 2                 Task 1                                 Create table posts
# 3                 Task 1                                Create table users
# 4   Single Table Queries  How many posts have been created by a user tha...
# 5   Single Table Queries                    How many posts have 0 comments?
# 6   Single Table Queries                    How many posts have 1 comments?
# 7   Single Table Queries            How many posts have 2 comments or more?
# 8   Single Table Queries        Find the 5 posts with the highest viewcount
# 9   Single Table Queries        Find the 5 posts with the highest viewcount
# 10  Single Table Queries       What are the 5 most frequent scores on posts
# 11  Single Table Queries  How many posts have the keyword "data" in thei...
# 12  Single Table Queries  What are the 5 most frequent commentcount for ...
# 13  Single Table Queries     What is the average reputation of table users?
# 14  Single Table Queries  What are the 5 most frequent commentcount for ...
# 15  Single Table Queries              What are the min reputation of users?
# 16  Single Table Queries              What are the max reputation of users?
# 17  Single Table Queries  What is the length of the body of 5 most viewe...
# 18  Single Table Queries  How many different locations are there in the ...
# 19  Single Table Queries             What are the top 5 locations of users?
# 20  Single Table Queries  Rank the days of the week from highest to lowe...
#
#                                                 query
# 0   \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1   \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2   \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3   \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4   \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...
# 5    SELECT commentcount, COUNT(*) AS number_of_co...
# 6    SELECT commentcount, COUNT(*) AS number_of_co...
# 7    SELECT commentcount, COUNT(*) AS number_of_co...
# 8    SELECT * From POSTS P\nORDER BY P.Viewcount\n...
# 9                               SELECT * FROM queries
# 10   SELECT Score, COUNT(*) AS Frequency\nFROM pos...
# 11  \nSELECT COUNT(*) AS NumPostsWithTagData\nFROM...
# 12   SELECT commentcount, COUNT(*) AS Frequency\nF...
# 13  \nSELECT AVG(reputation) AS average_reputation...
# 14  \nSELECT COUNT(*) AS NumPostsAcceptedAnswerId\...
# 15  \nSELECT MIN(Reputation) AS MinReputation,\nMA...
# 16  \nSELECT Max(Reputation) AS MaxReputation FROM...
# 17  \nSELECT LENGTH(Body) AS BodyLength\nFROM post...
# 18  \nSELECT COUNT(DISTINCT Location) AS NumberOfL...
# 19  \nSELECT Location, COUNT(*) AS Frequency\nFROM...
# 20  \nSELECT\nCAST (strftime('%w', CreationDate) A...

# %% [markdown]
# # Task 3: Cross Table Queries

# %% [markdown]
# ## Lifecycle Stage: Analyze
# Let's continue the analysis with our multi-table queries.

# %% [markdown]
# ### Cross Table Queries
#
# From the Template SQL Queries there are a series of queries requested. You are responsible for coding the result. Use the pattern above to accomplish the coding objective.  Copy and paste the question (column B Action) into a markdown cell and answer the query. Use the pattern that you have been using above.
#
# <div style="background-color:lemonchiffon; border:1px solid; padding:5px; margin:5px; font-weight:bold"><font color="crimson">
# TODO: Enter your code below.  Just keep on inserting cells as you need them.
#     </font></div>

# %%
sql = """
SELECT COUNT(*) AS NumPostsByUsersWithAboutMe
FROM posts
JOIN users ON posts.OwnerUserId = users.Id
WHERE users.AboutMe IS NOT NULL
"""
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#    NumPostsByUsersWithAboutMe
# 0                       17189

# %%
query_dict = {
              'task': ['Cross Table Queries'],
              'action': ['How many posts have been created by a user that has a filled out the "AboutMe" section?'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Cross Table Queries'],
#  'action': ['How many posts have been created by a user that has a filled out the "AboutMe" section?'],
#  'query': ['\nSELECT COUNT(*) AS NumPostsByUsersWithAboutMe\nFROM posts\nJOIN users ON posts.OwnerUserId = users.Id\nWHERE users.AboutMe IS NOT NULL\n']}

# %%
queries = pd.DataFrame(query_dict)
queries
# Out:
#                   task                                             action  \
# 0  Cross Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT COUNT(*) AS NumPostsByUsersWithAboutM...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
sql = """ SELECT COUNT(*) / (SELECT CAST(COUNT(*) AS FLOAT) FROM USERS WHERE ABOUTME !='') AS posts_per_user
    FROM POSTS P
    JOIN USERS U ON P.OWNERUSERID = U.ID
    WHERE U.ABOUTME !='';
    """
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#    posts_per_user
# 0        4.274807

# %%
query_dict = {
              'task': ['Cross Table Queries'],
              'action': ['Considering only the users with an "AboutMe," how many posts are there per user?'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Cross Table Queries'],
#  'action': ['Considering only the users with an "AboutMe," how many posts are there per user?'],
#  'query': [" SELECT COUNT(*) / (SELECT CAST(COUNT(*) AS FLOAT) FROM USERS WHERE ABOUTME !='') AS posts_per_user\n    FROM POSTS P\n    JOIN USERS U ON P.OWNERUSERID = U.ID\n    WHERE U.ABOUTME !='';\n    "]}

# %%
queries = pd.DataFrame(query_dict)
queries
# Out:
#                   task                                             action  \
# 0  Cross Table Queries  Considering only the users with an "AboutMe," ...
#
#                                                query
# 0   SELECT COUNT(*) / (SELECT CAST(COUNT(*) AS FL...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
#Post title is blank
sql = """
SELECT
    posts.Id,
    posts.title,
    COUNT(comments.Id) AS NumComments
FROM
    posts
LEFT JOIN
    comments ON posts.Id = comments.PostId
GROUP BY
    posts.Id, posts.title
ORDER BY
    NumComments DESC
LIMIT 10;
"""
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#        Id                                              Title  NumComments
# 0  386853                                               None           66
# 1  386556  Strategies for predicting 100 binary choices g...           34
# 2  395232                                               None           31
# 3  418910                                               None           31
# 4  402987  Evaluating Unbalanced Multiclass Classifiers: ...           27
# 5  386075   Avoiding social discrimination in model building           26
# 6  394118  Why do neural networks need so many training e...           24
# 7  398828                                               None           23
# 8  402950  Poisson Regression in R with individual fixed-...           23
# 9  396111             How do I intepret these t-SNE results?           22

# %%
query_dict = {
              'task': ['Cross Table Queries'],
              'action': ['what are the Top 10 posts in terms of number of comments?'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Cross Table Queries'],
#  'action': ['what are the Top 10 posts in terms of number of comments?'],
#  'query': ['\nSELECT\n    posts.Id,\n    posts.title,\n    COUNT(comments.Id) AS NumComments\nFROM\n    posts\nLEFT JOIN\n    comments ON posts.Id = comments.PostId\nGROUP BY\n    posts.Id, posts.title\nORDER BY\n    NumComments DESC\nLIMIT 10;\n']}

# %%
queries = pd.DataFrame(query_dict)
queries
# Out:
#                   task                                             action  \
# 0  Cross Table Queries  what are the Top 10 posts in terms of number o...
#
#                                                query
# 0  \nSELECT\n    posts.Id,\n    posts.title,\n   ...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
sql = """ SELECT
    posts.Id,
    posts.Title,
    posts.Score AS PostScore,
    COALESCE(SUM(comments.Score), 0) AS CommentScore,
    posts.Score + COALESCE(SUM(comments.Score), 0) AS CumulativeScore
FROM
    posts
LEFT JOIN
    comments ON posts.Id= comments.PostId
GROUP BY
    posts.Id, posts.Title, posts.Score
ORDER BY
    CumulativeScore DESC
LIMIT 10;
"""

result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#        Id                                              Title  PostScore  \
# 0  394118  Why do neural networks need so many training e...         64
# 1  394128                                               None        100
# 2  388578                                               None         80
# 3  398653                                               None         65
# 4  388566  Is it wrong to rephrase "1 in 80 deaths is cau...         56
# 5  431397                                               None        101
# 6  398646  What does "Scientists rise up against statisti...         61
# 7  421677                                               None         37
# 8  426878                                               None         93
# 9  420526                                               None         45
#
#    CommentScore  CumulativeScore
# 0           242              306
# 1            69              169
# 2            61              141
# 3            46              111
# 4            45              101
# 5             0              101
# 6            38               99
# 7            59               96
# 8             0               93
# 9            47               92

# %%
query_dict = {
              'task': ['Cross Table Queries'],
              'action': ['What are the Top 10 posts which have the highest cummulative (post score + comment score) score? '],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Cross Table Queries'],
#  'action': ['What are the Top 10 posts which have the highest cummulative (post score + comment score) score? '],
#  'query': [' SELECT\n    posts.Id,\n    posts.Title,\n    posts.Score AS PostScore,\n    COALESCE(SUM(comments.Score), 0) AS CommentScore,\n    posts.Score + COALESCE(SUM(comments.Score), 0) AS CumulativeScore\nFROM\n    posts\nLEFT JOIN\n    comments ON posts.Id= comments.PostId\nGROUP BY\n    posts.Id, posts.Title, posts.Score\nORDER BY\n    CumulativeScore DESC\nLIMIT 10;\n']}

# %%
queries = pd.DataFrame(query_dict)
queries
# Out:
#                   task                                             action  \
# 0  Cross Table Queries  What are the Top 10 posts which have the highe...
#
#                                                query
# 0   SELECT\n    posts.Id,\n    posts.Title,\n    ...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
sql = """ SELECT
    COUNT(users.Id) AS NumComments,
    users.Reputation
FROM
    users
LEFT JOIN
    comments ON users.Id = comments.UserId
GROUP BY
    users.Id
ORDER BY
    NumComments DESC
LIMIT 10;
"""

result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#    NumComments  Reputation
# 0         3301      223056
# 1         1153      228662
# 2         1024        2890
# 3          805       39200
# 4          691       17391
# 5          540       13485
# 6          536       41385
# 7          504        6482
# 8          492        8030
# 9          470       71548

# %%
sql = """
SELECT COUNT(*) AS Num_of_comments, C.USERID, U.REPUTATION
FROM COMMENTS C
JOIN USERS U ON U.ID = C.USERID
GROUP BY C.USERID , U.REPUTATION
 ORDER BY U.REPUTATION DESC LIMIT 10;
    """
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#    Num_of_comments  UserId  Reputation
# 0             1153     805      228662
# 1             3301     919      223056
# 2              370    7290      115531
# 3              349     686       85077
# 4              158   28666       75024
# 5              470   35989       71548
# 6              424    7224       65999
# 7              255    4253       59952
# 8              422    1352       59160
# 9              467   22311       51155

# %%
query_dict = {
              'task': ['cross Table Queries'],
              'action': ['Who are the top 10 users who comment the most? ?'],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['cross Table Queries'],
#  'action': ['Who are the top 10 users who comment the most? ?'],
#  'query': ['\nSELECT COUNT(*) AS Num_of_comments, C.USERID, U.REPUTATION\nFROM COMMENTS C\nJOIN USERS U ON U.ID = C.USERID\nGROUP BY C.USERID , U.REPUTATION\n ORDER BY U.REPUTATION DESC LIMIT 10;\n    ']}

# %%
queries = pd.DataFrame(query_dict)
queries
# Out:
#                   task                                            action  \
# 0  cross Table Queries  Who are the top 10 users who comment the most? ?
#
#                                                query
# 0  \nSELECT COUNT(*) AS Num_of_comments, C.USERID...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
sql = """
SELECT
    users.Id,
    COUNT(posts.Id) AS NumPosts,
    users.Reputation
FROM
    users
LEFT JOIN
    posts ON users.Id = posts.OwnerUserId
GROUP BY
    users.Id, users.Reputation
ORDER BY
    users.Reputation DESC
LIMIT 10;
"""
result = pd.read_sql(sql, con) # con is the connection to the database
result
# Out:
#       Id  NumPosts  Reputation
# 0    805       230      228662
# 1    919       203      223056
# 2   7290        35      115531
# 3    686       386       85077
# 4  28666         8       75024
# 5  35989       230       71548
# 6   7224       233       65999
# 7   4253        71       59952
# 8   1352       285       59160
# 9  22311       140       51155

# %%
query_dict = {
              'task': ['Cross table queries'],
              'action': ['Who are the top 10 users who post the most? '],
              'query': [sql]
             }
query_dict
# Out:
# {'task': ['Cross table queries'],
#  'action': ['Who are the top 10 users who post the most? '],
#  'query': ['\nSELECT\n    users.Id,\n    COUNT(posts.Id) AS NumPosts,\n    users.Reputation\nFROM\n    users\nLEFT JOIN\n    posts ON users.Id = posts.OwnerUserId\nGROUP BY\n    users.Id, users.Reputation\nORDER BY\n    users.Reputation DESC\nLIMIT 10;\n']}

# %%
queries = pd.DataFrame(query_dict)
queries
# Out:
#                   task                                        action  \
# 0  Cross table queries  Who are the top 10 users who post the most?
#
#                                                query
# 0  \nSELECT\n    users.Id,\n    COUNT(posts.Id) A...

# %%
# load query into sqlite
queries.to_sql('queries', con, if_exists='append', index=False)

# read back in to prove that it worked
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)
queries.head()
# Out:
#                    task                                             action  \
# 0  Single Table Queries  Which 5 users have viewed the most times and w...
# 1                Task 1                              Create table comments
# 2                Task 1                                 Create table posts
# 3                Task 1                                Create table users
# 4  Single Table Queries  How many posts have been created by a user tha...
#
#                                                query
# 0  \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1  \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2  \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3  \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4  \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...

# %%
queries
# Out:
#                     task                                             action  \
# 0   Single Table Queries  Which 5 users have viewed the most times and w...
# 1                 Task 1                              Create table comments
# 2                 Task 1                                 Create table posts
# 3                 Task 1                                Create table users
# 4   Single Table Queries  How many posts have been created by a user tha...
# 5   Single Table Queries                    How many posts have 0 comments?
# 6   Single Table Queries                    How many posts have 1 comments?
# 7   Single Table Queries            How many posts have 2 comments or more?
# 8   Single Table Queries        Find the 5 posts with the highest viewcount
# 9   Single Table Queries        Find the 5 posts with the highest viewcount
# 10  Single Table Queries       What are the 5 most frequent scores on posts
# 11  Single Table Queries  How many posts have the keyword "data" in thei...
# 12  Single Table Queries  What are the 5 most frequent commentcount for ...
# 13  Single Table Queries     What is the average reputation of table users?
# 14  Single Table Queries  What are the 5 most frequent commentcount for ...
# 15  Single Table Queries              What are the min reputation of users?
# 16  Single Table Queries              What are the max reputation of users?
# 17  Single Table Queries  What is the length of the body of 5 most viewe...
# 18  Single Table Queries  How many different locations are there in the ...
# 19  Single Table Queries             What are the top 5 locations of users?
# 20  Single Table Queries  Rank the days of the week from highest to lowe...
# 21   Cross Table Queries  How many posts have been created by a user tha...
# 22   Cross Table Queries  Considering only the users with an "AboutMe," ...
# 23   Cross Table Queries  what are the Top 10 posts in terms of number o...
# 24   Cross Table Queries  What are the Top 10 posts which have the highe...
# 25   cross Table Queries   Who are the top 10 users who comment the most? ?
# 26   Cross table queries       Who are the top 10 users who post the most?
#
#                                                 query
# 0   \nSELECT Id, SUM(Views) AS TotalViews\n    FRO...
# 1   \n    CREATE TABLE "comments" (\n    "Id" INTE...
# 2   \nCREATE TABLE "posts" (\n"Id" INTEGER,\n"Post...
# 3   \nCREATE TABLE "users" (\n"Id" INTEGER,\n"Repu...
# 4   \nSELECT COUNT(*) As NumPostsByUsersWithAboutM...
# 5    SELECT commentcount, COUNT(*) AS number_of_co...
# 6    SELECT commentcount, COUNT(*) AS number_of_co...
# 7    SELECT commentcount, COUNT(*) AS number_of_co...
# 8    SELECT * From POSTS P\nORDER BY P.Viewcount\n...
# 9                               SELECT * FROM queries
# 10   SELECT Score, COUNT(*) AS Frequency\nFROM pos...
# 11  \nSELECT COUNT(*) AS NumPostsWithTagData\nFROM...
# 12   SELECT commentcount, COUNT(*) AS Frequency\nF...
# 13  \nSELECT AVG(reputation) AS average_reputation...
# 14  \nSELECT COUNT(*) AS NumPostsAcceptedAnswerId\...
# 15  \nSELECT MIN(Reputation) AS MinReputation,\nMA...
# 16  \nSELECT Max(Reputation) AS MaxReputation FROM...
# 17  \nSELECT LENGTH(Body) AS BodyLength\nFROM post...
# 18  \nSELECT COUNT(DISTINCT Location) AS NumberOfL...
# 19  \nSELECT Location, COUNT(*) AS Frequency\nFROM...
# 20  \nSELECT\nCAST (strftime('%w', CreationDate) A...
# 21  \nSELECT COUNT(*) AS NumPostsByUsersWithAboutM...
# 22   SELECT COUNT(*) / (SELECT CAST(COUNT(*) AS FL...
# 23  \nSELECT\n    posts.Id,\n    posts.title,\n   ...
# 24   SELECT\n    posts.Id,\n    posts.Title,\n    ...
# 25  \nSELECT COUNT(*) AS Num_of_comments, C.USERID...
# 26  \nSELECT\n    users.Id,\n    COUNT(posts.Id) A...

# %% [markdown]
# # Task 4: Check the Queries Table
#
# Now let's tidy up and check the queries table.
#
# First let's check it's contents:

# %%
# %sql SELECT * FROM queries
# Out:
#  * sqlite:///chatdata.db
# Done.
# [('Single Table Queries', 'Which 5 users have viewed the most times and what is the sum of those views per user?', '\nSELECT Id, SUM(Views) AS TotalViews\n    FROM Users\n        GROUP BY Id\n            ORDER BY TotalViews DESC\n                LIMIT 5\n                '),
#  ('Task 1', 'Create table comments', '\n    CREATE TABLE "comments" (\n    "Id" INTEGER,\n    "PostId" INTEGER,\n    "Score" INTEGER,\n    "Text" TEXT,\n    "CreationDate" TEXT,\n    "UserId" INTEGER\n    )\n    '),
#  ('Task 1', 'Create table posts', '\nCREATE TABLE "posts" (\n"Id" INTEGER,\n"PostTypeId" INTEGER,\n"AcceptedAnswerId" INTEGER,\n"ParentId" INTEGER,\n"CreationDate" TEXT,\n"Score" INTEG ... (204 characters truncated) ... e" TEXT,\n"Tags" TEXT,\n"AnswerCount" INTEGER,\n"CommentCount" INTEGER,\n"FavoriteCount" INTEGER,\n"ClosedDate" TEXT,\n"CommunityOwnedDate" TEXT\n)\n'),
#  ('Task 1', 'Create table users ', '\nCREATE TABLE "users" (\n"Id" INTEGER,\n"Reputation" INTEGER,\n"CreationDate" TEXT,\n"DisplayName" TEXT,\n"LastAccessDate" TEXT,\n"WebsiteUrl" TEXT,\n"Location" TEXT,\n"AboutMe" TEXT,\n"Views" INTEGER,\n"UpVotes" INTEGER,\n"DownVotes" INTEGER,\n"ProfileImageUrl" TEXT,\n"AccountId" INTEGER\n)\n'),
#  ('Single Table Queries', 'How many posts have been created by a user that has a filled out the "AboutMe" section? ', '\nSELECT COUNT(*) As NumPostsByUsersWithAboutMe\nFrom posts\nJOIN users ON posts.OwnerUserId= users.Id\n                '),
#  ('Single Table Queries', 'How many posts have 0 comments?', ' SELECT commentcount, COUNT(*) AS number_of_comment_0\nFROM posts\nWHERE commentcount = 0;\n'),
#  ('Single Table Queries', 'How many posts have 1 comments?', ' SELECT commentcount, COUNT(*) AS number_of_comment_1\nFROM posts\nWHERE commentcount = 1;\n'),
#  ('Single Table Queries', 'How many posts have 2 comments or more?', ' SELECT commentcount, COUNT(*) AS number_of_comment_2\nFROM posts\nWHERE commentcount >= 2;\n'),
#  ('Single Table Queries', 'Find the 5 posts with the highest viewcount', ' SELECT * From POSTS P\nORDER BY P.Viewcount\nDESC LIMIT 5;\n'),
#  ('Single Table Queries', 'Find the 5 posts with the highest viewcount', 'SELECT * FROM queries'),
#  ('Single Table Queries', 'What are the 5 most frequent scores on posts', ' SELECT Score, COUNT(*) AS Frequency\nFROM posts\nGROUP BY Score\nORDER BY Frequency DESC, Score DESC\nLIMIT 5;\n'),
#  ('Single Table Queries', 'How many posts have the keyword "data" in their tags?', "\nSELECT COUNT(*) AS NumPostsWithTagData\nFROM posts\nWHERE Tags LIKE '%data%';\n"),
#  ('Single Table Queries', 'What are the 5 most frequent commentcount for posts?', ' SELECT commentcount, COUNT(*) AS Frequency\nFROM posts\nGROUP BY commentcount\nORDER BY Frequency DESC, commentcount DESC\nLIMIT 5;\n'),
#  ('Single Table Queries', 'What is the average reputation of table users?', '\nSELECT AVG(reputation) AS average_reputation_amount\nFROM users;\n'),
#  ('Single Table Queries', 'What are the 5 most frequent commentcount for posts?', '\nSELECT COUNT(*) AS NumPostsAcceptedAnswerId\nFROM posts\nWHERE AcceptedAnswerId > 0;\n'),
#  ('Single Table Queries', 'What are the min reputation of users?', '\nSELECT MIN(Reputation) AS MinReputation,\nMAX(Reputation) AS MaxReputation\nFROM users;\n'),
#  ('Single Table Queries', 'What are the max reputation of users?', '\nSELECT Max(Reputation) AS MaxReputation FROM users;\n'),
#  ('Single Table Queries', 'What is the length of the body of 5 most viewed posts?', '\nSELECT LENGTH(Body) AS BodyLength\nFROM posts\nORDER BY ViewCount DESC\nLIMIT 5;\n'),
#  ('Single Table Queries', 'How many different locations are there in the users table?', '\nSELECT COUNT(DISTINCT Location) AS NumberOfLocations\nFROM users;\n'),
#  ('Single Table Queries', 'What are the top 5 locations of users?', '\nSELECT Location, COUNT(*) AS Frequency\nFROM users\nWHERE Location >0\nGROUP BY Location\nORDER BY Frequency DESC\nLIMIT 5;\n'),
#  ('Single Table Queries', 'Rank the days of the week from highest to lowest in terms of the volume of ViewCount as a percentage?', "\nSELECT\nCAST (strftime('%w', CreationDate) AS INTEGER) AS DayOfWeek,\nSUM(ViewCount) AS DayCount,\nROUND(SUM(ViewCount) * 100.0 / SUM(SUM(ViewCount)) OVER (), 2) AS PercentageOfTotalViews\nFROM posts\nGROUP BY DayOfWeek\nORDER BY DayCount;\n"),
#  ('Cross Table Queries', 'How many posts have been created by a user that has a filled out the "AboutMe" section?', '\nSELECT COUNT(*) AS NumPostsByUsersWithAboutMe\nFROM posts\nJOIN users ON posts.OwnerUserId = users.Id\nWHERE users.AboutMe IS NOT NULL\n'),
#  ('Cross Table Queries', 'Considering only the users with an "AboutMe," how many posts are there per user?', " SELECT COUNT(*) / (SELECT CAST(COUNT(*) AS FLOAT) FROM USERS WHERE ABOUTME !='') AS posts_per_user\n    FROM POSTS P\n    JOIN USERS U ON P.OWNERUSERID = U.ID\n    WHERE U.ABOUTME !='';\n    "),
#  ('Cross Table Queries', 'what are the Top 10 posts in terms of number of comments?', '\nSELECT\n    posts.Id,\n    posts.title,\n    COUNT(comments.Id) AS NumComments\nFROM\n    posts\nLEFT JOIN\n    comments ON posts.Id = comments.PostId\nGROUP BY\n    posts.Id, posts.title\nORDER BY\n    NumComments DESC\nLIMIT 10;\n'),
#  ('Cross Table Queries', 'What are the Top 10 posts which have the highest cummulative (post score + comment score) score? ', ' SELECT\n    posts.Id,\n    posts.Title,\n    posts.Score AS PostScore,\n    COALESCE(SUM(comments.Score), 0) AS CommentScore,\n    posts.Score + COA ... (69 characters truncated) ... FT JOIN\n    comments ON posts.Id= comments.PostId\nGROUP BY\n    posts.Id, posts.Title, posts.Score\nORDER BY\n    CumulativeScore DESC\nLIMIT 10;\n'),
#  ('cross Table Queries', 'Who are the top 10 users who comment the most? ?', '\nSELECT COUNT(*) AS Num_of_comments, C.USERID, U.REPUTATION\nFROM COMMENTS C\nJOIN USERS U ON U.ID = C.USERID\nGROUP BY C.USERID , U.REPUTATION\n ORDER BY U.REPUTATION DESC LIMIT 10;\n    '),
#  ('Cross table queries', 'Who are the top 10 users who post the most? ', '\nSELECT\n    users.Id,\n    COUNT(posts.Id) AS NumPosts,\n    users.Reputation\nFROM\n    users\nLEFT JOIN\n    posts ON users.Id = posts.OwnerUserId\nGROUP BY\n    users.Id, users.Reputation\nORDER BY\n    users.Reputation DESC\nLIMIT 10;\n')]

# %% [markdown]
# ## Drop Duplicates
#
# You likely have some duplicates. Lets drop them.

# %%
# Read the queries table into pandas
sql = 'SELECT * FROM queries'
queries = pd.read_sql(sql, con)

# Drop duplicates
queries.drop_duplicates(inplace = True) # drop duplicates

# %% [markdown]
# ## Case Issues

# %% [markdown]
# Remember, SQL is case insensitive. Pandas IS case sensitive. Lets deal with this now by making all of the text uppercase.

# %%
for col in queries.columns:
    queries[col] = queries[col].str.upper()

queries
# Out:
#                     task                                             action  \
# 0   SINGLE TABLE QUERIES  WHICH 5 USERS HAVE VIEWED THE MOST TIMES AND W...
# 1                 TASK 1                              CREATE TABLE COMMENTS
# 2                 TASK 1                                 CREATE TABLE POSTS
# 3                 TASK 1                                CREATE TABLE USERS
# 4   SINGLE TABLE QUERIES  HOW MANY POSTS HAVE BEEN CREATED BY A USER THA...
# 5   SINGLE TABLE QUERIES                    HOW MANY POSTS HAVE 0 COMMENTS?
# 6   SINGLE TABLE QUERIES                    HOW MANY POSTS HAVE 1 COMMENTS?
# 7   SINGLE TABLE QUERIES            HOW MANY POSTS HAVE 2 COMMENTS OR MORE?
# 8   SINGLE TABLE QUERIES        FIND THE 5 POSTS WITH THE HIGHEST VIEWCOUNT
# 9   SINGLE TABLE QUERIES        FIND THE 5 POSTS WITH THE HIGHEST VIEWCOUNT
# 10  SINGLE TABLE QUERIES       WHAT ARE THE 5 MOST FREQUENT SCORES ON POSTS
# 11  SINGLE TABLE QUERIES  HOW MANY POSTS HAVE THE KEYWORD "DATA" IN THEI...
# 12  SINGLE TABLE QUERIES  WHAT ARE THE 5 MOST FREQUENT COMMENTCOUNT FOR ...
# 13  SINGLE TABLE QUERIES     WHAT IS THE AVERAGE REPUTATION OF TABLE USERS?
# 14  SINGLE TABLE QUERIES  WHAT ARE THE 5 MOST FREQUENT COMMENTCOUNT FOR ...
# 15  SINGLE TABLE QUERIES              WHAT ARE THE MIN REPUTATION OF USERS?
# 16  SINGLE TABLE QUERIES              WHAT ARE THE MAX REPUTATION OF USERS?
# 17  SINGLE TABLE QUERIES  WHAT IS THE LENGTH OF THE BODY OF 5 MOST VIEWE...
# 18  SINGLE TABLE QUERIES  HOW MANY DIFFERENT LOCATIONS ARE THERE IN THE ...
# 19  SINGLE TABLE QUERIES             WHAT ARE THE TOP 5 LOCATIONS OF USERS?
# 20  SINGLE TABLE QUERIES  RANK THE DAYS OF THE WEEK FROM HIGHEST TO LOWE...
# 21   CROSS TABLE QUERIES  HOW MANY POSTS HAVE BEEN CREATED BY A USER THA...
# 22   CROSS TABLE QUERIES  CONSIDERING ONLY THE USERS WITH AN "ABOUTME," ...
# 23   CROSS TABLE QUERIES  WHAT ARE THE TOP 10 POSTS IN TERMS OF NUMBER O...
# 24   CROSS TABLE QUERIES  WHAT ARE THE TOP 10 POSTS WHICH HAVE THE HIGHE...
# 25   CROSS TABLE QUERIES   WHO ARE THE TOP 10 USERS WHO COMMENT THE MOST? ?
# 26   CROSS TABLE QUERIES       WHO ARE THE TOP 10 USERS WHO POST THE MOST?
#
#                                                 query
# 0   \nSELECT ID, SUM(VIEWS) AS TOTALVIEWS\n    FRO...
# 1   \n    CREATE TABLE "COMMENTS" (\n    "ID" INTE...
# 2   \nCREATE TABLE "POSTS" (\n"ID" INTEGER,\n"POST...
# 3   \nCREATE TABLE "USERS" (\n"ID" INTEGER,\n"REPU...
# 4   \nSELECT COUNT(*) AS NUMPOSTSBYUSERSWITHABOUTM...
# 5    SELECT COMMENTCOUNT, COUNT(*) AS NUMBER_OF_CO...
# 6    SELECT COMMENTCOUNT, COUNT(*) AS NUMBER_OF_CO...
# 7    SELECT COMMENTCOUNT, COUNT(*) AS NUMBER_OF_CO...
# 8    SELECT * FROM POSTS P\nORDER BY P.VIEWCOUNT\n...
# 9                               SELECT * FROM QUERIES
# 10   SELECT SCORE, COUNT(*) AS FREQUENCY\nFROM POS...
# 11  \nSELECT COUNT(*) AS NUMPOSTSWITHTAGDATA\nFROM...
# 12   SELECT COMMENTCOUNT, COUNT(*) AS FREQUENCY\nF...
# 13  \nSELECT AVG(REPUTATION) AS AVERAGE_REPUTATION...
# 14  \nSELECT COUNT(*) AS NUMPOSTSACCEPTEDANSWERID\...
# 15  \nSELECT MIN(REPUTATION) AS MINREPUTATION,\nMA...
# 16  \nSELECT MAX(REPUTATION) AS MAXREPUTATION FROM...
# 17  \nSELECT LENGTH(BODY) AS BODYLENGTH\nFROM POST...
# 18  \nSELECT COUNT(DISTINCT LOCATION) AS NUMBEROFL...
# 19  \nSELECT LOCATION, COUNT(*) AS FREQUENCY\nFROM...
# 20  \nSELECT\nCAST (STRFTIME('%W', CREATIONDATE) A...
# 21  \nSELECT COUNT(*) AS NUMPOSTSBYUSERSWITHABOUTM...
# 22   SELECT COUNT(*) / (SELECT CAST(COUNT(*) AS FL...
# 23  \nSELECT\n    POSTS.ID,\n    POSTS.TITLE,\n   ...
# 24   SELECT\n    POSTS.ID,\n    POSTS.TITLE,\n    ...
# 25  \nSELECT COUNT(*) AS NUM_OF_COMMENTS, C.USERID...
# 26  \nSELECT\n    USERS.ID,\n    COUNT(POSTS.ID) A...

# %%
# Write the now deduped uppercase dataframe back to sqlite and replace the table
queries.to_sql('queries', con, if_exists='replace', index=False)
# Out:
# 27

# %% [markdown]
# ## Use Case
#
# Now that we have this queries table, lets give you some ideas about how you would use it.
#
# Suppose you wanted to find all of the queries where you did a GROUP BY:

# %%
# %%sql
# SELECT query
#     FROM queries
#         WHERE query LIKE '%GROUP BY%'
# Out:
#  * sqlite:///chatdata.db
# Done.
# [('\nSELECT ID, SUM(VIEWS) AS TOTALVIEWS\n    FROM USERS\n        GROUP BY ID\n            ORDER BY TOTALVIEWS DESC\n                LIMIT 5\n                ',),
#  (' SELECT SCORE, COUNT(*) AS FREQUENCY\nFROM POSTS\nGROUP BY SCORE\nORDER BY FREQUENCY DESC, SCORE DESC\nLIMIT 5;\n',),
#  (' SELECT COMMENTCOUNT, COUNT(*) AS FREQUENCY\nFROM POSTS\nGROUP BY COMMENTCOUNT\nORDER BY FREQUENCY DESC, COMMENTCOUNT DESC\nLIMIT 5;\n',),
#  ('\nSELECT LOCATION, COUNT(*) AS FREQUENCY\nFROM USERS\nWHERE LOCATION >0\nGROUP BY LOCATION\nORDER BY FREQUENCY DESC\nLIMIT 5;\n',),
#  ("\nSELECT\nCAST (STRFTIME('%W', CREATIONDATE) AS INTEGER) AS DAYOFWEEK,\nSUM(VIEWCOUNT) AS DAYCOUNT,\nROUND(SUM(VIEWCOUNT) * 100.0 / SUM(SUM(VIEWCOUNT)) OVER (), 2) AS PERCENTAGEOFTOTALVIEWS\nFROM POSTS\nGROUP BY DAYOFWEEK\nORDER BY DAYCOUNT;\n",),
#  ('\nSELECT\n    POSTS.ID,\n    POSTS.TITLE,\n    COUNT(COMMENTS.ID) AS NUMCOMMENTS\nFROM\n    POSTS\nLEFT JOIN\n    COMMENTS ON POSTS.ID = COMMENTS.POSTID\nGROUP BY\n    POSTS.ID, POSTS.TITLE\nORDER BY\n    NUMCOMMENTS DESC\nLIMIT 10;\n',),
#  (' SELECT\n    POSTS.ID,\n    POSTS.TITLE,\n    POSTS.SCORE AS POSTSCORE,\n    COALESCE(SUM(COMMENTS.SCORE), 0) AS COMMENTSCORE,\n    POSTS.SCORE + COA ... (69 characters truncated) ... FT JOIN\n    COMMENTS ON POSTS.ID= COMMENTS.POSTID\nGROUP BY\n    POSTS.ID, POSTS.TITLE, POSTS.SCORE\nORDER BY\n    CUMULATIVESCORE DESC\nLIMIT 10;\n',),
#  ('\nSELECT COUNT(*) AS NUM_OF_COMMENTS, C.USERID, U.REPUTATION\nFROM COMMENTS C\nJOIN USERS U ON U.ID = C.USERID\nGROUP BY C.USERID , U.REPUTATION\n ORDER BY U.REPUTATION DESC LIMIT 10;\n    ',),
#  ('\nSELECT\n    USERS.ID,\n    COUNT(POSTS.ID) AS NUMPOSTS,\n    USERS.REPUTATION\nFROM\n    USERS\nLEFT JOIN\n    POSTS ON USERS.ID = POSTS.OWNERUSERID\nGROUP BY\n    USERS.ID, USERS.REPUTATION\nORDER BY\n    USERS.REPUTATION DESC\nLIMIT 10;\n',)]

# %% [markdown]
# ## Now Your Turn
# Find the queries that have 'DISTINCT' in them. You can do it with the %sql command or with Pandas and sql.
#
# <div style="background-color:lemonchiffon; border:1px solid; padding:5px; margin:5px; font-weight:bold"><font color="crimson">
# TODO: Complete the following code cell
#     </font></div>

# %%
# Distinct

# %%sql
SELECT query
    FROM queries
        WHERE query LIKE 'DISTINCT'
# Out:
#  * sqlite:///chatdata.db
# Done.
# []

# %%
#Make alterations for the frequency part

# %% [markdown]
# # Close SQLite
#
# It is good practise to close all relational databases as soon as you are finished updating them.

# %%
con.close()

# %% [markdown]
# # All Done!
#
# Great job. You now have a good idea for how to use sql and pandas with sql. You can create your own databases from csv files and you can do extensive querying using sql. These are valuable skills that will take you a long ways in todays technological world.
